# %% [markdown]
# ### Check GPU

# %%
# Data manipulation
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

#Pytorch
import torch
from torch.utils.data import Dataset, DataLoader
import torchvision
import torchvision.transforms as transforms
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

from PIL import Image
import matplotlib.pyplot as plt

from torchsummary import summary
from torch.utils.tensorboard import SummaryWriter
from torchvision import models
from tqdm.notebook import tqdm

# %%
from tensorboard import version; print(version.VERSION)
# Out:
# 2.4.1

# %%
# check GPU support
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda')

# %% [markdown]
# ### Dataset and dataloader

# %%
PATH = 'C:/Users/trang/OneDrive - HKUST Connect/COMP_4211/pa2/'

# %% [markdown]
# - resize all the images to a size of 32x32
# - convert them to single-channel images
#
# Dataset.getitem() should return:
# - two 32x32, single-channel images
# - one target label

# %%
class ImageDataset(Dataset):
    def __init__(self, info_file, index_file, image_dir, transform=None):
        self.info_df = pd.read_csv(info_file)  
        self.index_df = pd.read_csv(index_file, sep=',',header =None,names=['index','source'])
        #self.classes = np.array(self.info_df.columns[1:]) # image labels 
        self.image_dir = image_dir
        self.transform = transform

    def __getitem__(self, idx):
        img_index1 = self.info_df.iloc[idx, 0]
        img_name1 = os.path.join(self.image_dir, str(self.index_df.iloc[img_index1, 1])[5:])
        image1 = Image.open(img_name1)
        image1 = image1.convert('L')
        
        img_index2 = self.info_df.iloc[idx, 1]
        img_name2 = os.path.join(self.image_dir, str(self.index_df.iloc[img_index2, 1])[5:])
        image2 = Image.open(img_name2)
        image2 = image2.convert('L')
        
        label = self.info_df.iloc[idx, 2]
        
        if self.transform is not None:
            image1 = self.transform(image1)
            image2 = self.transform(image2)
        
        return image1, image2, label

    def __len__(self):
        return len(self.info_df)

# %% [markdown]
# Check dataset

# %%
# more transform functions can refer to https://pytorch.org/docs/stable/torchvision/transforms.html
transform = transforms.Compose(
    [transforms.Resize((32,32)),
     transforms.ToTensor(),    # range [0, 255]  -> [0.0,1.0] Convert a PIL Image or numpy.ndarray (H x W x C)  to tensor (C x H x W) 
     transforms.Normalize((0.5,), (0.5,))   # channel=（channel-mean）/std  -> [-1, 1]
     ])

# if the image has one channel (grayscale), normalise operation will be 
#transforms.Normalize((0.5, ), (0.5, ))

# %%
dataset = ImageDataset(PATH + 'train.csv', PATH + 'index.txt',PATH, transform=transform)

# %% [markdown]
# Load image dataset

# %%
train_set = ImageDataset(PATH + 'train.csv', PATH + 'index.txt', PATH, transform=transform)
valid_set = ImageDataset(PATH + 'valid.csv', PATH + 'index.txt', PATH, transform=transform)
test_set = ImageDataset(PATH + 'test.csv', PATH + 'index.txt', PATH, transform=transform)

train_loader = DataLoader(train_set, batch_size=128, shuffle=True)
valid_loader = DataLoader(valid_set, batch_size=128, shuffle=False)
test_loader = DataLoader(test_set, batch_size=128,shuffle=False)

# %% [markdown]
# ### Define Convolutional Neural Network

# %%
class SiameseNetwork(nn.Module):
    def __init__(self, aggregation_type):
        super(SiameseNetwork, self).__init__()
        
        self.cnn = nn.Sequential(
            nn.Conv2d(in_channels=1, out_channels=32, kernel_size=3, padding = 1), 
            nn.BatchNorm2d(32),
            nn.ReLU(inplace=True),
            
            nn.Conv2d(in_channels=32, out_channels=32, kernel_size=3, padding = 1),  
            nn.BatchNorm2d(32),
            nn.ReLU(inplace=True),
            
            nn.MaxPool2d(kernel_size=2, stride=2),
            
            nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3, padding = 1),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True),
            
            nn.Conv2d(in_channels=64, out_channels=128, kernel_size=3, padding = 1),
            nn.BatchNorm2d(128),
            nn.ReLU(inplace=True),
            
            nn.Conv2d(in_channels=128, out_channels=256, kernel_size=3, padding = 1),
            nn.BatchNorm2d(256),
            nn.ReLU(inplace=True),
            
            nn.Conv2d(in_channels=256, out_channels=512, kernel_size=3, padding = 1),
            nn.BatchNorm2d(512),
            nn.ReLU(inplace=True),
            
            nn.AvgPool2d(kernel_size=16,stride=1),
            
            nn.Flatten(),
            
        )
        self.aggregation_type = aggregation_type
        if(self.aggregation_type=="concatenation"):
            self.fc1 = nn.Linear(1024,512) # concatenation
        elif(self.aggregation_type=="absolute_substraction"):
            self.fc1 = nn.Linear(512,512) # absolute substraction
        self.drop_out = nn.Dropout(p=0.5)
        self.fc2 = nn.Linear(512,1)

    def forward(self, image1, image2):
        
        image1 = self.cnn(image1)
        image2 = self.cnn(image2)
        
        if(self.aggregation_type=="concatenation"):
            h3 = torch.cat((image1,image2),1) #concatenation
        elif(self.aggregation_type=="absolute_substraction"):
            h3 = torch.abs(torch.sub(image1, image2)) #absolute substraction

        output = F.relu(self.fc1(h3))
        output = self.drop_out(output)
        output = self.fc2(output)
        output = nn.Sigmoid()(output)
        #output = torch.reshape(output,(-1,))
        
        return output

# %% [markdown]
# #### Function count the total number of trainable parameters

# %% [markdown]
# When aggregation function is absolute difference

# %%
net_absolute_substraction = SiameseNetwork("absolute_substraction").cuda()
summary(net_absolute_substraction, [(1, 32, 32),(1, 32, 32)])
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 32, 32, 32]             320
#        BatchNorm2d-2           [-1, 32, 32, 32]              64
#               ReLU-3           [-1, 32, 32, 32]               0
#             Conv2d-4           [-1, 32, 32, 32]           9,248
#        BatchNorm2d-5           [-1, 32, 32, 32]              64
#               ReLU-6           [-1, 32, 32, 32]               0
#          MaxPool2d-7           [-1, 32, 16, 16]               0
#             Conv2d-8           [-1, 64, 16, 16]          18,496
#        BatchNorm2d-9           [-1, 64, 16, 16]             128
#              ReLU-10           [-1, 64, 16, 16]               0
#            Conv2d-11          [-1, 128, 16, 16]          73,856
#       BatchNorm2d-12          [-1, 128, 16, 16]             256
#              ReLU-13          [-1, 128, 16, 16]               0
#            Conv2d-14          [-1, 256, 16, 16]         295,168
#       BatchNorm2d-15          [-1, 256, 16, 16]             512
#              ReLU-16          [-1, 256, 16, 16]               0
#            Conv2d-17          [-1, 512, 16, 16]       1,180,160
#       BatchNorm2d-18          [-1, 512, 16, 16]           1,024
#              ReLU-19          [-1, 512, 16, 16]               0
#         AvgPool2d-20            [-1, 512, 1, 1]               0
#           Flatten-21                  [-1, 512]               0
#            Conv2d-22           [-1, 32, 32, 32]             320
#       BatchNorm2d-23           [-1, 32, 32, 32]              64
#              ReLU-24           [-1, 32, 32, 32]               0
#            Conv2d-25           [-1, 32, 32, 32]           9,248
#       BatchNorm2d-26           [-1, 32, 32, 32]              64
#              ReLU-27           [-1, 32, 32, 32]               0
#         MaxPool2d-28           [-1, 32, 16, 16]               0
#            Conv2d-29           [-1, 64, 16, 16]          18,496
#       BatchNorm2d-30           [-1, 64, 16, 16]             128
#              ReLU-31           [-1, 64, 16, 16]               0
#            Conv2d-32          [-1, 128, 16, 16]          73,856
#       BatchNorm2d-33          [-1, 128, 16, 16]             256
#              ReLU-34          [-1, 128, 16, 16]               0
#            Conv2d-35          [-1, 256, 16, 16]         295,168
#       BatchNorm2d-36          [-1, 256, 16, 16]             512
#              ReLU-37          [-1, 256, 16, 16]               0
#            Conv2d-38          [-1, 512, 16, 16]       1,180,160
#       BatchNorm2d-39          [-1, 512, 16, 16]           1,024
#              ReLU-40          [-1, 512, 16, 16]               0
#         AvgPool2d-41            [-1, 512, 1, 1]               0
#           Flatten-42                  [-1, 512]               0
#            Linear-43                  [-1, 512]         262,656
#           Dropout-44                  [-1, 512]               0
#            Linear-45                    [-1, 1]             513
# ================================================================
# Total params: 3,421,761
# Trainable params: 3,421,761
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 4.00
# Forward/backward pass size (MB): 14.40
# Params size (MB): 13.05
# Estimated Total Size (MB): 31.45
# ----------------------------------------------------------------

# %% [markdown]
# When aggregation function is concatenation

# %%
net_concatenation = SiameseNetwork("concatenation").cuda()
summary(net_concatenation, [(1, 32, 32),(1,32,32)])
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 32, 32, 32]             320
#        BatchNorm2d-2           [-1, 32, 32, 32]              64
#               ReLU-3           [-1, 32, 32, 32]               0
#             Conv2d-4           [-1, 32, 32, 32]           9,248
#        BatchNorm2d-5           [-1, 32, 32, 32]              64
#               ReLU-6           [-1, 32, 32, 32]               0
#          MaxPool2d-7           [-1, 32, 16, 16]               0
#             Conv2d-8           [-1, 64, 16, 16]          18,496
#        BatchNorm2d-9           [-1, 64, 16, 16]             128
#              ReLU-10           [-1, 64, 16, 16]               0
#            Conv2d-11          [-1, 128, 16, 16]          73,856
#       BatchNorm2d-12          [-1, 128, 16, 16]             256
#              ReLU-13          [-1, 128, 16, 16]               0
#            Conv2d-14          [-1, 256, 16, 16]         295,168
#       BatchNorm2d-15          [-1, 256, 16, 16]             512
#              ReLU-16          [-1, 256, 16, 16]               0
#            Conv2d-17          [-1, 512, 16, 16]       1,180,160
#       BatchNorm2d-18          [-1, 512, 16, 16]           1,024
#              ReLU-19          [-1, 512, 16, 16]               0
#         AvgPool2d-20            [-1, 512, 1, 1]               0
#           Flatten-21                  [-1, 512]               0
#            Conv2d-22           [-1, 32, 32, 32]             320
#       BatchNorm2d-23           [-1, 32, 32, 32]              64
#              ReLU-24           [-1, 32, 32, 32]               0
#            Conv2d-25           [-1, 32, 32, 32]           9,248
#       BatchNorm2d-26           [-1, 32, 32, 32]              64
#              ReLU-27           [-1, 32, 32, 32]               0
#         MaxPool2d-28           [-1, 32, 16, 16]               0
#            Conv2d-29           [-1, 64, 16, 16]          18,496
#       BatchNorm2d-30           [-1, 64, 16, 16]             128
#              ReLU-31           [-1, 64, 16, 16]               0
#            Conv2d-32          [-1, 128, 16, 16]          73,856
#       BatchNorm2d-33          [-1, 128, 16, 16]             256
#              ReLU-34          [-1, 128, 16, 16]               0
#            Conv2d-35          [-1, 256, 16, 16]         295,168
#       BatchNorm2d-36          [-1, 256, 16, 16]             512
#              ReLU-37          [-1, 256, 16, 16]               0
#            Conv2d-38          [-1, 512, 16, 16]       1,180,160
#       BatchNorm2d-39          [-1, 512, 16, 16]           1,024
#              ReLU-40          [-1, 512, 16, 16]               0
#         AvgPool2d-41            [-1, 512, 1, 1]               0
#           Flatten-42                  [-1, 512]               0
#            Linear-43                  [-1, 512]         524,800
#           Dropout-44                  [-1, 512]               0
#            Linear-45                    [-1, 1]             513
# ================================================================
# Total params: 3,683,905
# Trainable params: 3,683,905
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 4.00
# Forward/backward pass size (MB): 14.40
# Params size (MB): 14.05
# Estimated Total Size (MB): 32.45
# ----------------------------------------------------------------

# %% [markdown]
# ### 4.2.3 Training and Validation

# %%
def save_checkpoint(save_path, model, optimizer, val_loss):
    if save_path==None:
        return
    save_path = save_path 
    state_dict = {'model_state_dict': model.state_dict(),
                  'optimizer_state_dict': optimizer.state_dict(),
                  'val_loss': val_loss}

    torch.save(state_dict, save_path)
    print(f'Model saved to {save_path}')

def load_checkpoint(save_path, model, optimizer):
    save_path = save_path #f'cifar_net.pt'
    state_dict = torch.load(save_path)
    model.load_state_dict(state_dict['model_state_dict'])
    optimizer.load_state_dict(state_dict['optimizer_state_dict'])
    val_loss = state_dict['val_loss']
    print(f'Model loaded from {save_path}, with val loss: {val_loss}')
    return val_loss

def TRAIN(net, train_loader, valid_loader,  num_epochs, criterion, optimizer, val_loss,threshold, device, save_name):
    
    step_list = []
    training_loss_list = []
    valid_loss_list = []
    
    if val_loss==None:
        best_val_loss = float("Inf")  
    else: 
        best_val_loss=val_loss
        print('Resume training')


    no_step = 0;
    for epoch in range(num_epochs):  # loop over the dataset multiple times
        net.train()
        running_loss = 0.0
        running_corrects = 0
        for input1,input2, labels in tqdm(train_loader):
            
            no_step +=1
            input1 = input1.to(device)
            input2 = input2.to(device)
            labels = labels.to(device)
            
            labels = labels.unsqueeze(1)
            labels = labels.float()

            '''Training of the model'''
            # Forward pass
            outputs = net(input1, input2)
            
            loss = criterion(outputs, labels)

            # Backward and optimize
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            training_loss = loss.item()
            running_loss += loss.item()
            preds = torch.gt(outputs, threshold).int()                       
            running_corrects += torch.sum(preds == labels.data)            
            
            with torch.no_grad():
                net.eval()
                running_loss_valid = 0.0
                running_corrects_valid = 0
                for input1_valid,input2_valid, labels_valid in tqdm(valid_loader):
            
                    input1_valid = input1_valid.to(device)
                    input2_valid = input2_valid.to(device)
                    labels_valid = labels_valid.to(device)

                    labels_valid = labels_valid.unsqueeze(1)
                    labels_valid = labels_valid.float()

                    outputs_valid = net(input1_valid,input2_valid)
                    loss_valid = criterion(outputs_valid, labels_valid)

                    running_loss_valid += loss_valid.item()
                    preds_valid = torch.gt(outputs_valid, threshold).int()
                    running_corrects_valid += torch.sum(preds_valid == labels_valid.data)

                valid_loss = running_loss_valid / len(valid_loader)
                valid_acc = running_corrects_valid / float(len(valid_loader.dataset))
            
            if(no_step%10==0):
                step_list.append(no_step)
                training_loss_list.append(training_loss)
                valid_loss_list.append(valid_loss)
                
                print("step ",no_step," training loss: ",training_loss,", validation loss: ",valid_loss,"\n")
            

        train_loss = running_loss / len(train_loader)
        train_acc = running_corrects / float(len(train_loader.dataset))

        with torch.no_grad():
            net.eval()
            running_loss = 0.0
            running_corrects = 0
            for input1,input2, labels in tqdm(valid_loader):
            
                input1 = input1.to(device)
                input2 = input2.to(device)
                labels = labels.to(device)
                
                labels = labels.unsqueeze(1)
                labels = labels.float()

                outputs = net(input1,input2)
                loss = criterion(outputs, labels)

                running_loss += loss.item()
                preds = torch.gt(outputs, threshold).int()
                running_corrects += torch.sum(preds == labels.data)

            valid_loss = running_loss / len(valid_loader)
            valid_acc = running_corrects / float(len(valid_loader.dataset))

        print('Epoch [{}/{}], Train Loss: {:.4f}, Train Acc: {:.4f}, Valid Loss: {:.4f},  Valid Acc: {:.4f}'
              .format(epoch+1, num_epochs, train_loss, train_acc, valid_loss, valid_acc))

        if valid_loss < best_val_loss:
            best_val_loss = valid_loss
            save_checkpoint(save_name, net, optimizer, best_val_loss)
    
    plt.plot(step_list,training_loss_list,label="Training Loss")
    plt.plot(step_list,valid_loss_list,label="Validation Loss")
    plt.xlabel('Number of steps')
    # Set a title of the current axes.
    plt.title('Traning and Validation loss curves')
    # show a legend on the plot
    plt.legend()
    # Display a figure.
    plt.show()
    
    print('Finished Training')

# %%
model = SiameseNetwork("absolute_substraction").cuda()
num_epochs = 20
best_val_loss = None
criterion = nn.BCELoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)
threshold = 0.5
save_path = f'cifar_net.pt'
model = model.to(device)


TRAIN(model, train_loader, valid_loader, num_epochs, criterion, optimizer, best_val_loss,threshold, device, save_path)
# Out:
#   0%|          | 0/39 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
# step  10  training loss:  0.6913034319877625 , validation loss:  0.6905862987041473
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
# step  20  training loss:  0.6612142324447632 , validation loss:  0.6887470980485281
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
# step  30  training loss:  0.6871194839477539 , validation loss:  0.6896719435850779
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
# Epoch [1/20], Train Loss: 0.6902, Train Acc: 0.5286, Valid Loss: 0.6964,  Valid Acc: 0.5114
# Model saved to cifar_net.pt
#   0%|          | 0/39 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
# step  40  training loss:  0.7856748104095459 , validation loss:  0.7016427516937256
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
# step  50  training loss:  0.6847344636917114 , validation loss:  0.6959441701571146
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
# step  60  training loss:  0.6904948949813843 , validation loss:  0.6929634610811869
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
# step  70  training loss:  0.6837524771690369 , validation loss:  0.6886238555113474
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
# Epoch [2/20], Train Loss: 0.6921, Train Acc: 0.5288, Valid Loss: 0.6914,  Valid Acc: 0.5600
# Model saved to cifar_net.pt
#   0%|          | 0/39 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
# step  80  training loss:  0.6908509731292725 , validation loss:  0.6900302072366079
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
# step  90  training loss:  0.7093752026557922 , validation loss:  0.6849000255266825
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
# step  100  training loss:  0.6868829727172852 , validation loss:  0.6967499951521555
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
# step  110  training loss:  0.6804223656654358 , validation loss:  0.6823859512805939
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
# Epoch [3/20], Train Loss: 0.7237, Train Acc: 0.5349, Valid Loss: 0.6884,  Valid Acc: 0.5643
# Model saved to cifar_net.pt
#   0%|          | 0/39 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
# step  120  training loss:  0.6896616220474243 , validation loss:  0.6926733354727427
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
# step  130  training loss:  0.6802096366882324 , validation loss:  0.6863932907581329
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
# step  140  training loss:  0.6968095302581787 , validation loss:  0.7058448294798533
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
# step  150  training loss:  0.6796553134918213 , validation loss:  0.686836838722229
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
# Epoch [4/20], Train Loss: 0.6986, Train Acc: 0.5341, Valid Loss: 0.6883,  Valid Acc: 0.5643
# Model saved to cifar_net.pt
#   0%|          | 0/39 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
# step  160  training loss:  0.6852574348449707 , validation loss:  0.6844936807950338
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
# step  170  training loss:  0.6793867945671082 , validation loss:  0.6838470002015432
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
# step  180  training loss:  0.6963814496994019 , validation loss:  0.6790348688761393
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
# step  190  training loss:  0.6641418933868408 , validation loss:  0.6808802982171377
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
# Epoch [5/20], Train Loss: 0.6812, Train Acc: 0.5512, Valid Loss: 0.6876,  Valid Acc: 0.5557
# Model saved to cifar_net.pt
#   0%|          | 0/39 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
# step  200  training loss:  0.6820616722106934 , validation loss:  0.6908670365810394
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
# step  210  training loss:  0.6597412824630737 , validation loss:  0.6728383799393972
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
# step  220  training loss:  0.6682623624801636 , validation loss:  0.6826442082722982
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
# step  230  training loss:  0.6674087047576904 , validation loss:  0.6641404529412588
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
# Epoch [6/20], Train Loss: 0.6732, Train Acc: 0.5845, Valid Loss: 0.6659,  Valid Acc: 0.6243
# Model saved to cifar_net.pt
#   0%|          | 0/39 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
# step  240  training loss:  0.6859347820281982 , validation loss:  0.6585167845090231
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
# step  250  training loss:  0.6566445231437683 , validation loss:  0.6440402468045553
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
# step  260  training loss:  0.6012611985206604 , validation loss:  0.6402881344159445
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
# step  270  training loss:  0.6662245988845825 , validation loss:  0.6536116202672323
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
# Epoch [7/20], Train Loss: 0.6506, Train Acc: 0.6257, Valid Loss: 0.6488,  Valid Acc: 0.6357
# Model saved to cifar_net.pt
#   0%|          | 0/39 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
# step  280  training loss:  0.6426464319229126 , validation loss:  0.6599472860495249
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
# step  290  training loss:  0.6175024509429932 , validation loss:  0.6438314815362295
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
# step  300  training loss:  0.6317284107208252 , validation loss:  0.6358422935009003
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
# step  310  training loss:  0.6548489928245544 , validation loss:  0.6528270641962687
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
# Epoch [8/20], Train Loss: 0.6375, Train Acc: 0.6451, Valid Loss: 0.6498,  Valid Acc: 0.6314
#   0%|          | 0/39 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
# step  320  training loss:  0.6102243065834045 , validation loss:  0.651301383972168
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
# step  330  training loss:  0.626958966255188 , validation loss:  0.6338277558485667
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
# step  340  training loss:  0.557790219783783 , validation loss:  0.6291158696015676
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
# step  350  training loss:  0.6462136507034302 , validation loss:  0.616524209578832
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
# Epoch [9/20], Train Loss: 0.6222, Train Acc: 0.6639, Valid Loss: 0.6164,  Valid Acc: 0.6643
# Model saved to cifar_net.pt
#   0%|          | 0/39 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
# step  360  training loss:  0.6035822629928589 , validation loss:  0.611686497926712
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
# step  370  training loss:  0.6465498208999634 , validation loss:  0.6229207019011179
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
# step  380  training loss:  0.6419286131858826 , validation loss:  0.6178189019362131
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
# step  390  training loss:  0.5981495976448059 , validation loss:  0.6488105456034342
#   0%|          | 0/6 [00:00<?, ?it/s]
# Epoch [10/20], Train Loss: 0.6172, Train Acc: 0.6835, Valid Loss: 0.6488,  Valid Acc: 0.6571
#   0%|          | 0/39 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
# step  400  training loss:  0.6260261535644531 , validation loss:  0.6465757191181183
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
# step  410  training loss:  0.6671072244644165 , validation loss:  0.622613380352656
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
# step  420  training loss:  0.603661060333252 , validation loss:  0.6101517677307129
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
# Epoch [11/20], Train Loss: 0.6090, Train Acc: 0.6784, Valid Loss: 0.6231,  Valid Acc: 0.6657
#   0%|          | 0/39 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
# step  430  training loss:  0.7407074570655823 , validation loss:  0.6257235109806061
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
# step  440  training loss:  0.5493775010108948 , validation loss:  0.6127248605092367
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
# step  450  training loss:  0.6418380737304688 , validation loss:  0.5998665392398834
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
# step  460  training loss:  0.5968788862228394 , validation loss:  0.6032024919986725
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
# Epoch [12/20], Train Loss: 0.5937, Train Acc: 0.6910, Valid Loss: 0.6115,  Valid Acc: 0.6814
# Model saved to cifar_net.pt
#   0%|          | 0/39 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
# step  470  training loss:  0.5608826875686646 , validation loss:  0.6266879041989645
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
# step  480  training loss:  0.5975022315979004 , validation loss:  0.606076161066691
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
# step  490  training loss:  0.618377685546875 , validation loss:  0.6064575612545013
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
# step  500  training loss:  0.6369889378547668 , validation loss:  0.6120804150899252
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
# Epoch [13/20], Train Loss: 0.5791, Train Acc: 0.7073, Valid Loss: 0.6082,  Valid Acc: 0.6871
# Model saved to cifar_net.pt
#   0%|          | 0/39 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
# step  510  training loss:  0.5585182905197144 , validation loss:  0.6254175206025442
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
# step  520  training loss:  0.5653592348098755 , validation loss:  0.6000954409440359
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
# step  530  training loss:  0.5366870164871216 , validation loss:  0.6129709084828695
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
# step  540  training loss:  0.5350016355514526 , validation loss:  0.6055356959501902
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
# Epoch [14/20], Train Loss: 0.5773, Train Acc: 0.7176, Valid Loss: 0.5900,  Valid Acc: 0.6829
# Model saved to cifar_net.pt
#   0%|          | 0/39 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
# step  550  training loss:  0.50516277551651 , validation loss:  0.6032590766747793
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
# step  560  training loss:  0.5573102831840515 , validation loss:  0.6184670279423395
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
# step  570  training loss:  0.5638124942779541 , validation loss:  0.5955480337142944
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
# step  580  training loss:  0.6206200122833252 , validation loss:  0.6298318157593409
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
# Epoch [15/20], Train Loss: 0.5638, Train Acc: 0.7155, Valid Loss: 0.6090,  Valid Acc: 0.6886
#   0%|          | 0/39 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
# step  590  training loss:  0.49337053298950195 , validation loss:  0.5823769768079122
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
# step  600  training loss:  0.5220577120780945 , validation loss:  0.5927766263484955
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
# step  610  training loss:  0.5402844548225403 , validation loss:  0.5936135252316793
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
# step  620  training loss:  0.5493226051330566 , validation loss:  0.59251669049263
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
# Epoch [16/20], Train Loss: 0.5564, Train Acc: 0.7241, Valid Loss: 0.5776,  Valid Acc: 0.7014
# Model saved to cifar_net.pt
#   0%|          | 0/39 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
# step  630  training loss:  0.5248607397079468 , validation loss:  0.5897170007228851
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
# step  640  training loss:  0.5983055233955383 , validation loss:  0.587274894118309
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
# step  650  training loss:  0.5845305323600769 , validation loss:  0.6510505278905233
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
# step  660  training loss:  0.6040050387382507 , validation loss:  0.6004002392292023
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
# Epoch [17/20], Train Loss: 0.5639, Train Acc: 0.7224, Valid Loss: 0.6227,  Valid Acc: 0.6886
#   0%|          | 0/39 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
# step  670  training loss:  0.5930137038230896 , validation loss:  0.5860891590515772
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
# step  680  training loss:  0.5848585963249207 , validation loss:  0.6049768428007761
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
# step  690  training loss:  0.5069926977157593 , validation loss:  0.5934049487113953
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
# step  700  training loss:  0.5558208227157593 , validation loss:  0.5707451204458872
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
# Epoch [18/20], Train Loss: 0.5426, Train Acc: 0.7343, Valid Loss: 0.6045,  Valid Acc: 0.7086
#   0%|          | 0/39 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
# step  710  training loss:  0.5078690052032471 , validation loss:  0.5886011272668839
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
# step  720  training loss:  0.5600134134292603 , validation loss:  0.5851288040479025
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
# step  730  training loss:  0.4851115345954895 , validation loss:  0.622066080570221
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
# step  740  training loss:  0.5205658674240112 , validation loss:  0.5887312342723211
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
# Epoch [19/20], Train Loss: 0.5470, Train Acc: 0.7351, Valid Loss: 0.5841,  Valid Acc: 0.7029
#   0%|          | 0/39 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
# step  750  training loss:  0.5326414704322815 , validation loss:  0.5759615103403727
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
# step  760  training loss:  0.5504605174064636 , validation loss:  0.5966817140579224
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
# step  770  training loss:  0.5214332342147827 , validation loss:  0.5842714210351309
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
# step  780  training loss:  0.551605761051178 , validation loss:  0.5720308721065521
#   0%|          | 0/6 [00:00<?, ?it/s]
# Epoch [20/20], Train Loss: 0.5229, Train Acc: 0.7500, Valid Loss: 0.5720,  Valid Acc: 0.7000
# Model saved to cifar_net.pt
# Finished Training

# %% [markdown]
# ### 4.2.4 Evaluation

# %%
def eval(net, valid_loader):
    max_valid_acc = 0
    optimal_threshold = 0
    threshold_array = np.arange(0.0, 1.0, 0.02)
    for threshold in threshold_array:
        print(threshold)
        with torch.no_grad():
            running_loss = 0.0
            running_corrects = 0
            for input1,input2, labels in tqdm(valid_loader):

                input1 = input1.to(device)
                input2 = input2.to(device)

                labels = labels.to(device)
                labels = labels.unsqueeze(1)
                labels = labels.float()

                outputs = net(input1,input2)
                preds = torch.gt(outputs, threshold).int()

                running_corrects += torch.sum(preds == labels.data)

            valid_acc = running_corrects / float(len(valid_loader.dataset))
            print("valid_acc: ", valid_acc)
            if(valid_acc > max_valid_acc):
                max_valid_acc = valid_acc
                optimal_threshold = threshold
    return max_valid_acc,optimal_threshold

# %%
max_valid_acc,optimal_threshold = eval(model, valid_loader)
# Out:
# 0.0
#   0%|          | 0/6 [00:00<?, ?it/s]
# valid_acc:  tensor(0.5000, device='cuda:0')
# 0.02
#   0%|          | 0/6 [00:00<?, ?it/s]
# valid_acc:  tensor(0.5000, device='cuda:0')
# 0.04
#   0%|          | 0/6 [00:00<?, ?it/s]
# valid_acc:  tensor(0.5000, device='cuda:0')
# 0.06
#   0%|          | 0/6 [00:00<?, ?it/s]
# valid_acc:  tensor(0.5014, device='cuda:0')
# 0.08
#   0%|          | 0/6 [00:00<?, ?it/s]
# valid_acc:  tensor(0.5029, device='cuda:0')
# 0.1
#   0%|          | 0/6 [00:00<?, ?it/s]
# valid_acc:  tensor(0.5100, device='cuda:0')
# 0.12
#   0%|          | 0/6 [00:00<?, ?it/s]
# valid_acc:  tensor(0.5129, device='cuda:0')
# 0.14
#   0%|          | 0/6 [00:00<?, ?it/s]
# valid_acc:  tensor(0.5229, device='cuda:0')
# 0.16
#   0%|          | 0/6 [00:00<?, ?it/s]
# valid_acc:  tensor(0.5514, device='cuda:0')
# 0.18
#   0%|          | 0/6 [00:00<?, ?it/s]
# valid_acc:  tensor(0.5729, device='cuda:0')
# 0.2
#   0%|          | 0/6 [00:00<?, ?it/s]
# valid_acc:  tensor(0.6029, device='cuda:0')
# 0.22
#   0%|          | 0/6 [00:00<?, ?it/s]
# valid_acc:  tensor(0.6343, device='cuda:0')
# 0.24
#   0%|          | 0/6 [00:00<?, ?it/s]
# valid_acc:  tensor(0.6643, device='cuda:0')
# 0.26
#   0%|          | 0/6 [00:00<?, ?it/s]
# valid_acc:  tensor(0.6871, device='cuda:0')
# 0.28
#   0%|          | 0/6 [00:00<?, ?it/s]
# valid_acc:  tensor(0.6943, device='cuda:0')
# 0.3
#   0%|          | 0/6 [00:00<?, ?it/s]
# valid_acc:  tensor(0.7043, device='cuda:0')
# 0.32
#   0%|          | 0/6 [00:00<?, ?it/s]
# valid_acc:  tensor(0.7171, device='cuda:0')
# 0.34
#   0%|          | 0/6 [00:00<?, ?it/s]
# valid_acc:  tensor(0.7200, device='cuda:0')
# 0.36
#   0%|          | 0/6 [00:00<?, ?it/s]
# valid_acc:  tensor(0.7200, device='cuda:0')
# 0.38
#   0%|          | 0/6 [00:00<?, ?it/s]
# valid_acc:  tensor(0.7186, device='cuda:0')
# 0.4
#   0%|          | 0/6 [00:00<?, ?it/s]
# valid_acc:  tensor(0.7114, device='cuda:0')
# 0.42
#   0%|          | 0/6 [00:00<?, ?it/s]
# valid_acc:  tensor(0.7100, device='cuda:0')
# 0.44
#   0%|          | 0/6 [00:00<?, ?it/s]
# valid_acc:  tensor(0.7071, device='cuda:0')
# 0.46
#   0%|          | 0/6 [00:00<?, ?it/s]
# valid_acc:  tensor(0.7000, device='cuda:0')
# 0.48
#   0%|          | 0/6 [00:00<?, ?it/s]
# valid_acc:  tensor(0.7000, device='cuda:0')
# 0.5
#   0%|          | 0/6 [00:00<?, ?it/s]
# valid_acc:  tensor(0.7000, device='cuda:0')
# 0.52
#   0%|          | 0/6 [00:00<?, ?it/s]
# valid_acc:  tensor(0.7029, device='cuda:0')
# 0.54
#   0%|          | 0/6 [00:00<?, ?it/s]
# valid_acc:  tensor(0.7000, device='cuda:0')
# 0.56
#   0%|          | 0/6 [00:00<?, ?it/s]
# valid_acc:  tensor(0.6886, device='cuda:0')
# 0.58
#   0%|          | 0/6 [00:00<?, ?it/s]
# valid_acc:  tensor(0.6857, device='cuda:0')
# 0.6
#   0%|          | 0/6 [00:00<?, ?it/s]
# valid_acc:  tensor(0.6843, device='cuda:0')
# 0.62
#   0%|          | 0/6 [00:00<?, ?it/s]
# valid_acc:  tensor(0.6800, device='cuda:0')
# 0.64
#   0%|          | 0/6 [00:00<?, ?it/s]
# valid_acc:  tensor(0.6700, device='cuda:0')
# 0.66
#   0%|          | 0/6 [00:00<?, ?it/s]
# valid_acc:  tensor(0.6686, device='cuda:0')
# 0.68
#   0%|          | 0/6 [00:00<?, ?it/s]
# valid_acc:  tensor(0.6586, device='cuda:0')
# 0.7000000000000001
#   0%|          | 0/6 [00:00<?, ?it/s]
# valid_acc:  tensor(0.6543, device='cuda:0')
# 0.72
#   0%|          | 0/6 [00:00<?, ?it/s]
# valid_acc:  tensor(0.6386, device='cuda:0')
# 0.74
#   0%|          | 0/6 [00:00<?, ?it/s]
# valid_acc:  tensor(0.6214, device='cuda:0')
# 0.76
#   0%|          | 0/6 [00:00<?, ?it/s]
# valid_acc:  tensor(0.6200, device='cuda:0')
# 0.78
#   0%|          | 0/6 [00:00<?, ?it/s]
# valid_acc:  tensor(0.6029, device='cuda:0')
# 0.8
#   0%|          | 0/6 [00:00<?, ?it/s]
# valid_acc:  tensor(0.5971, device='cuda:0')
# 0.8200000000000001
#   0%|          | 0/6 [00:00<?, ?it/s]
# valid_acc:  tensor(0.5729, device='cuda:0')
# 0.84
#   0%|          | 0/6 [00:00<?, ?it/s]
# valid_acc:  tensor(0.5614, device='cuda:0')
# 0.86
#   0%|          | 0/6 [00:00<?, ?it/s]
# valid_acc:  tensor(0.5429, device='cuda:0')
# 0.88
#   0%|          | 0/6 [00:00<?, ?it/s]
# valid_acc:  tensor(0.5286, device='cuda:0')
# 0.9
#   0%|          | 0/6 [00:00<?, ?it/s]
# valid_acc:  tensor(0.5157, device='cuda:0')
# 0.92
#   0%|          | 0/6 [00:00<?, ?it/s]
# valid_acc:  tensor(0.5043, device='cuda:0')
# 0.9400000000000001
#   0%|          | 0/6 [00:00<?, ?it/s]
# valid_acc:  tensor(0.5014, device='cuda:0')
# 0.96
#   0%|          | 0/6 [00:00<?, ?it/s]
# valid_acc:  tensor(0.5000, device='cuda:0')
# 0.98
#   0%|          | 0/6 [00:00<?, ?it/s]
# valid_acc:  tensor(0.5000, device='cuda:0')

# %%
print(max_valid_acc)
# Out:
# tensor(0.7200, device='cuda:0')

# %%
print(optimal_threshold)
# Out:
# 0.34

# %% [markdown]
# ### 4.2.5 Improving your Model

# %% [markdown]
# #### D. Architecture

# %% [markdown]
# #### Adopting the VGG-11

# %%
class ImageDatasetRGB(Dataset):
    def __init__(self, info_file, index_file, image_dir, transform=None):
        self.info_df = pd.read_csv(info_file)  
        self.index_df = pd.read_csv(index_file, sep=',',header =None,names=['index','source'])
        #self.classes = np.array(self.info_df.columns[1:]) # image labels 
        self.image_dir = image_dir
        self.transform = transform

    def __getitem__(self, idx):
        img_index1 = self.info_df.iloc[idx, 0]
        img_name1 = os.path.join(self.image_dir, str(self.index_df.iloc[img_index1, 1])[5:])
        image1 = Image.open(img_name1)
        image1 = image1.convert('RGB')
        
        img_index2 = self.info_df.iloc[idx, 1]
        img_name2 = os.path.join(self.image_dir, str(self.index_df.iloc[img_index2, 1])[5:])
        image2 = Image.open(img_name2)
        image2 = image2.convert('RGB')
        
        label = self.info_df.iloc[idx, 2]
        
        if self.transform is not None:
            image1 = self.transform(image1)
            image2 = self.transform(image2)
        
        return image1, image2, label

    def __len__(self):
        return len(self.info_df)

# %%
transform = transforms.Compose(
    [transforms.Resize((64,64)), 
     transforms.ToTensor(),    # range [0, 255]  -> [0.0,1.0] Convert a PIL Image or numpy.ndarray (H x W x C)  to tensor (C x H x W) 
     transforms.Normalize((0.5, 0.5, 0.5 ), (0.5, 0.5, 0.5))   # channel=（channel-mean）/std  -> [-1, 1]
     ])

# %%
train_setRGB = ImageDatasetRGB(PATH + 'train.csv', PATH + 'index.txt', PATH, transform=transform)
valid_setRGB = ImageDatasetRGB(PATH + 'valid.csv', PATH + 'index.txt', PATH, transform=transform)
test_setRGB = ImageDatasetRGB(PATH + 'test.csv', PATH + 'index.txt', PATH, transform=transform)

train_loaderRGB = DataLoader(train_setRGB, batch_size=56, shuffle=True)
valid_loaderRGB = DataLoader(valid_setRGB, batch_size=56, shuffle=False)
test_loaderRGB = DataLoader(test_setRGB, batch_size=56,shuffle=False)

# %%
class Net(nn.Module):
    def __init__(self, aggregation_type):
        super(Net, self).__init__()
        
        self.cnn = nn.Sequential(
            nn.Conv2d(in_channels=3, out_channels=64, kernel_size=3, padding = 1), 
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True),
            
            nn.MaxPool2d(kernel_size=2, stride=2),
            
            nn.Conv2d(in_channels=64, out_channels=128, kernel_size=3, padding = 1),  
            nn.BatchNorm2d(128),
            nn.ReLU(inplace=True),
            
            nn.MaxPool2d(kernel_size=2, stride=2),
            
            nn.Conv2d(in_channels=128, out_channels=256, kernel_size=3, padding = 1),
            nn.BatchNorm2d(256),
            nn.ReLU(inplace=True),
            
            nn.Conv2d(in_channels=256, out_channels=256, kernel_size=3, padding = 1),
            nn.BatchNorm2d(256),
            nn.ReLU(inplace=True),
            
            nn.MaxPool2d(kernel_size=2, stride=2),
            
            nn.Conv2d(in_channels=256, out_channels=512, kernel_size=3, padding = 1),
            nn.BatchNorm2d(512),
            nn.ReLU(inplace=True),
            
            nn.Conv2d(in_channels=512, out_channels=512, kernel_size=3, padding = 1),
            nn.BatchNorm2d(512),
            nn.ReLU(inplace=True),
            
            nn.MaxPool2d(kernel_size=2, stride=2),
            
            nn.Conv2d(in_channels=512, out_channels=512, kernel_size=3, padding = 1),
            nn.BatchNorm2d(512),
            nn.ReLU(inplace=True),
            
            nn.Conv2d(in_channels=512, out_channels=512, kernel_size=3, padding = 1),
            nn.BatchNorm2d(512),
            nn.ReLU(inplace=True),
            
            nn.MaxPool2d(kernel_size=2, stride=2),
            
            nn.AvgPool2d(kernel_size=2,stride=1),
            
            nn.Flatten(),
            
        )
        self.aggregation_type = aggregation_type
        if(self.aggregation_type=="concatenation"):
            self.fc1 = nn.Linear(1024,512) # concatenation
        elif(self.aggregation_type=="absolute_substraction"):
            self.fc1 = nn.Linear(512,512) # absolute substraction
        self.drop_out = nn.Dropout(p=0.5)
        self.fc2 = nn.Linear(512,512)
        self.fc3 = nn.Linear(512,1)

    def forward(self, image1, image2):
        
        image1 = self.cnn(image1)
        image2 = self.cnn(image2)
        
        if(self.aggregation_type=="concatenation"):
            h3 = torch.cat((image1,image2),1) #concatenation
        elif(self.aggregation_type=="absolute_substraction"):
            h3 = torch.abs(torch.sub(image1, image2)) #absolute substraction
        print(h3)
        output = self.fc1(h3)
        output = F.relu(output)
        output = self.drop_out(output)
        
        output = F.relu(self.fc2(output))
        output = self.drop_out(output)
        
        output = self.fc3(output)
        output = nn.Sigmoid()(output)
        
        return output

# %%
netVGG_11_absolute_substraction = Net("absolute_substraction").cuda()
summary(netVGG_11_absolute_substraction, [(3, 64, 64),(3, 64, 64)])
# Out:
# tensor([[0.0153, 0.3313, 0.0210,  ..., 0.6140, 0.1444, 0.6300],
#         [0.2536, 0.4267, 0.1682,  ..., 0.3946, 0.0357, 0.5505]],
#        device='cuda:0', grad_fn=<AbsBackward>)
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 64, 64]           1,792
#        BatchNorm2d-2           [-1, 64, 64, 64]             128
#               ReLU-3           [-1, 64, 64, 64]               0
#          MaxPool2d-4           [-1, 64, 32, 32]               0
#             Conv2d-5          [-1, 128, 32, 32]          73,856
#        BatchNorm2d-6          [-1, 128, 32, 32]             256
#               ReLU-7          [-1, 128, 32, 32]               0
#          MaxPool2d-8          [-1, 128, 16, 16]               0
#             Conv2d-9          [-1, 256, 16, 16]         295,168
#       BatchNorm2d-10          [-1, 256, 16, 16]             512
#              ReLU-11          [-1, 256, 16, 16]               0
#            Conv2d-12          [-1, 256, 16, 16]         590,080
#       BatchNorm2d-13          [-1, 256, 16, 16]             512
#              ReLU-14          [-1, 256, 16, 16]               0
#         MaxPool2d-15            [-1, 256, 8, 8]               0
#            Conv2d-16            [-1, 512, 8, 8]       1,180,160
#       BatchNorm2d-17            [-1, 512, 8, 8]           1,024
#              ReLU-18            [-1, 512, 8, 8]               0
#            Conv2d-19            [-1, 512, 8, 8]       2,359,808
#       BatchNorm2d-20            [-1, 512, 8, 8]           1,024
#              ReLU-21            [-1, 512, 8, 8]               0
#         MaxPool2d-22            [-1, 512, 4, 4]               0
#            Conv2d-23            [-1, 512, 4, 4]       2,359,808
#       BatchNorm2d-24            [-1, 512, 4, 4]           1,024
#              ReLU-25            [-1, 512, 4, 4]               0
#            Conv2d-26            [-1, 512, 4, 4]       2,359,808
#       BatchNorm2d-27            [-1, 512, 4, 4]           1,024
#              ReLU-28            [-1, 512, 4, 4]               0
#         MaxPool2d-29            [-1, 512, 2, 2]               0
#         AvgPool2d-30            [-1, 512, 1, 1]               0
#           Flatten-31                  [-1, 512]               0
#            Conv2d-32           [-1, 64, 64, 64]           1,792
#       BatchNorm2d-33           [-1, 64, 64, 64]             128
#              ReLU-34           [-1, 64, 64, 64]               0
#         MaxPool2d-35           [-1, 64, 32, 32]               0
#            Conv2d-36          [-1, 128, 32, 32]          73,856
#       BatchNorm2d-37          [-1, 128, 32, 32]             256
#              ReLU-38          [-1, 128, 32, 32]               0
#         MaxPool2d-39          [-1, 128, 16, 16]               0
#            Conv2d-40          [-1, 256, 16, 16]         295,168
#       BatchNorm2d-41          [-1, 256, 16, 16]             512
#              ReLU-42          [-1, 256, 16, 16]               0
#            Conv2d-43          [-1, 256, 16, 16]         590,080
#       BatchNorm2d-44          [-1, 256, 16, 16]             512
#              ReLU-45          [-1, 256, 16, 16]               0
#         MaxPool2d-46            [-1, 256, 8, 8]               0
#            Conv2d-47            [-1, 512, 8, 8]       1,180,160
#       BatchNorm2d-48            [-1, 512, 8, 8]           1,024
#              ReLU-49            [-1, 512, 8, 8]               0
#            Conv2d-50            [-1, 512, 8, 8]       2,359,808
#       BatchNorm2d-51            [-1, 512, 8, 8]           1,024
#              ReLU-52            [-1, 512, 8, 8]               0
#         MaxPool2d-53            [-1, 512, 4, 4]               0
#            Conv2d-54            [-1, 512, 4, 4]       2,359,808
#       BatchNorm2d-55            [-1, 512, 4, 4]           1,024
#              ReLU-56            [-1, 512, 4, 4]               0
#            Conv2d-57            [-1, 512, 4, 4]       2,359,808
#       BatchNorm2d-58            [-1, 512, 4, 4]           1,024
#              ReLU-59            [-1, 512, 4, 4]               0
#         MaxPool2d-60            [-1, 512, 2, 2]               0
#         AvgPool2d-61            [-1, 512, 1, 1]               0
#           Flatten-62                  [-1, 512]               0
#            Linear-63                  [-1, 512]         262,656
#           Dropout-64                  [-1, 512]               0
#            Linear-65                  [-1, 512]         262,656
#           Dropout-66                  [-1, 512]               0
#            Linear-67                    [-1, 1]             513
# ================================================================
# Total params: 18,977,793
# Trainable params: 18,977,793
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 576.00
# Forward/backward pass size (MB): 29.69
# Params size (MB): 72.39
# Estimated Total Size (MB): 678.08
# ----------------------------------------------------------------

# %%
def TRAIN_VGG(net, train_loader, valid_loader,  num_epochs, criterion, optimizer, val_loss,threshold, device, save_name):
    
    step_list = []
    training_loss_list = []
    valid_loss_list = []
    
    if val_loss==None:
        best_val_loss = float("Inf")  
    else: 
        best_val_loss=val_loss
        print('Resume training')


    no_step = 0;
    for epoch in range(num_epochs):  # loop over the dataset multiple times
        net.train()
        running_loss = 0.0
        running_corrects = 0
        for input1,input2, labels in tqdm(train_loader):
            
            no_step +=1
            input1 = input1.to(device)
            input2 = input2.to(device)
            labels = labels.to(device)
            
            labels = labels.unsqueeze(1)
            labels = labels.float()

            '''Training of the model'''
            # Forward pass
            outputs = net(input1, input2)
            
            loss = criterion(outputs, labels)

            # Backward and optimize
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            training_loss = loss.item()
            running_loss += loss.item()
            preds = torch.gt(outputs, threshold).int()                       
            running_corrects += torch.sum(preds == labels.data)            
            
            with torch.no_grad():
                net.eval()
                running_loss_valid = 0.0
                running_corrects_valid = 0
                for input1_valid,input2_valid, labels_valid in tqdm(valid_loader,leave=False):
            
                    input1_valid = input1_valid.to(device)
                    input2_valid = input2_valid.to(device)
                    labels_valid = labels_valid.to(device)

                    labels_valid = labels_valid.unsqueeze(1)
                    labels_valid = labels_valid.float()

                    outputs_valid = net(input1_valid,input2_valid)
                    loss_valid = criterion(outputs_valid, labels_valid)

                    running_loss_valid += loss_valid.item()
                    preds_valid = torch.gt(outputs_valid, threshold).int()
                    running_corrects_valid += torch.sum(preds_valid == labels_valid.data)

                valid_loss = running_loss_valid / len(valid_loader)
                valid_acc = running_corrects_valid / float(len(valid_loader.dataset))
            
            if(no_step%10==0):
                step_list.append(no_step)
                training_loss_list.append(training_loss)
                valid_loss_list.append(valid_loss)
                
                print("step ",no_step," training loss: ",training_loss,", validation loss: ",valid_loss,"\n")
            

        train_loss = running_loss / len(train_loader)
        train_acc = running_corrects / float(len(train_loader.dataset))

        with torch.no_grad():
            net.eval()
            running_loss = 0.0
            running_corrects = 0
            for input1,input2, labels in tqdm(valid_loader):
            
                input1 = input1.to(device)
                input2 = input2.to(device)
                labels = labels.to(device)
                
                labels = labels.unsqueeze(1)
                labels = labels.float()

                outputs = net(input1,input2)
                loss = criterion(outputs, labels)

                running_loss += loss.item()
                preds = torch.gt(outputs, threshold).int()
                running_corrects += torch.sum(preds == labels.data)

            valid_loss = running_loss / len(valid_loader)
            valid_acc = running_corrects / float(len(valid_loader.dataset))

        print('Epoch [{}/{}], Train Loss: {:.4f}, Train Acc: {:.4f}, Valid Loss: {:.4f},  Valid Acc: {:.4f}'
              .format(epoch+1, num_epochs, train_loss, train_acc, valid_loss, valid_acc))

        if valid_loss < best_val_loss:
            best_val_loss = valid_loss
            save_checkpoint(save_name, net, optimizer, best_val_loss)
    
    plt.plot(step_list,training_loss_list,label="Training Loss")
    plt.plot(step_list,valid_loss_list,label="Validation Loss")
    plt.xlabel('Number of steps')
    # Set a title of the current axes.
    plt.title('Traning and Validation loss curves')
    # show a legend on the plot
    plt.legend()
    # Display a figure.
    plt.show()
    
    print('Finished Training')

# %%
model = Net("absolute_substraction").cuda()
num_epochs = 20
best_val_loss = None
criterion = nn.BCELoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)
threshold = 0.5
save_path = f'cifar_net.pt'
model = model.to(device)


TRAIN_VGG(model, train_loaderRGB, valid_loaderRGB, num_epochs, criterion, optimizer, best_val_loss,threshold, device, save_path)
# Out:
#   0%|          | 0/88 [00:00<?, ?it/s]
# tensor([[0.2629, 0.1223, 0.0068,  ..., 0.0403, 0.3771, 0.2891],
#         [0.0651, 0.0784, 0.0990,  ..., 0.0105, 0.2835, 0.0980],
#         [1.2755, 0.5362, 0.6608,  ..., 0.8017, 0.4895, 0.0449],
#         ...,
#         [0.2107, 0.0681, 0.0159,  ..., 0.4657, 0.9319, 0.3602],
#         [0.1512, 0.4526, 0.2014,  ..., 0.4833, 0.3735, 0.6377],
#         [0.2602, 1.0243, 0.2746,  ..., 0.3403, 0.0993, 0.3548]],
#        device='cuda:0', grad_fn=<AbsBackward>)
#   0%|          | 0/13 [00:00<?, ?it/s]
# tensor([[1.2421e-03, 5.8029e-04, 8.7414e-04,  ..., 6.7884e-05, 0.0000e+00,
#          0.0000e+00],
#         [1.2741e-03, 5.6505e-05, 1.5243e-04,  ..., 4.0896e-04, 0.0000e+00,
#          0.0000e+00],
#         [7.3999e-04, 3.0923e-04, 5.7172e-04,  ..., 2.6736e-04, 0.0000e+00,
#          0.0000e+00],
#         ...,
#         [1.4240e-03, 1.2184e-03, 1.9349e-04,  ..., 1.3696e-03, 0.0000e+00,
#          0.0000e+00],
#         [8.6523e-04, 5.4653e-04, 1.1429e-05,  ..., 8.9289e-04, 0.0000e+00,
#          0.0000e+00],
#         [1.2816e-03, 3.6227e-04, 2.9100e-04,  ..., 1.3388e-03, 0.0000e+00,
#          0.0000e+00]], device='cuda:0')
# tensor([[9.7961e-04, 8.8487e-04, 2.2227e-04,  ..., 1.3114e-03, 0.0000e+00,
#          0.0000e+00],
#         [8.1700e-04, 8.4855e-04, 4.6094e-04,  ..., 6.7490e-04, 0.0000e+00,
#          0.0000e+00],
#         [1.5797e-03, 4.7554e-04, 7.2744e-04,  ..., 1.5942e-03, 0.0000e+00,
#          0.0000e+00],
#         ...,
#         [8.6098e-04, 2.0426e-04, 7.6017e-04,  ..., 3.0696e-04, 0.0000e+00,
#          0.0000e+00],
#         [9.9047e-04, 4.5070e-04, 3.4198e-05,  ..., 4.3512e-04, 0.0000e+00,
#          0.0000e+00],
#         [9.4403e-05, 1.3541e-04, 2.1315e-04,  ..., 1.2329e-04, 0.0000e+00,
#          0.0000e+00]], device='cuda:0')
# tensor([[0.0004, 0.0002, 0.0002,  ..., 0.0003, 0.0000, 0.0000],
#         [0.0021, 0.0010, 0.0004,  ..., 0.0012, 0.0000, 0.0000],
#         [0.0023, 0.0008, 0.0006,  ..., 0.0014, 0.0000, 0.0000],
#         ...,
#         [0.0008, 0.0011, 0.0003,  ..., 0.0009, 0.0000, 0.0000],
#         [0.0014, 0.0008, 0.0005,  ..., 0.0013, 0.0000, 0.0000],
#         [0.0005, 0.0002, 0.0007,  ..., 0.0005, 0.0000, 0.0000]],
#        device='cuda:0')
# tensor([[5.5754e-04, 7.0501e-06, 2.8078e-04,  ..., 1.0780e-03, 0.0000e+00,
#          0.0000e+00],
#         [4.0483e-04, 7.8031e-04, 3.2421e-04,  ..., 8.3360e-04, 0.0000e+00,
#          0.0000e+00],
#         [8.0669e-05, 1.4214e-04, 2.7343e-04,  ..., 8.4523e-04, 0.0000e+00,
#          0.0000e+00],
#         ...,
#         [7.4371e-04, 2.3757e-04, 6.5954e-04,  ..., 1.6489e-04, 0.0000e+00,
#          0.0000e+00],
#         [1.3946e-03, 9.3197e-04, 6.8740e-04,  ..., 6.5245e-04, 0.0000e+00,
#          0.0000e+00],
#         [2.4896e-04, 2.0131e-04, 4.7503e-04,  ..., 9.2154e-04, 0.0000e+00,
#          0.0000e+00]], device='cuda:0')
# tensor([[0.0006, 0.0004, 0.0001,  ..., 0.0006, 0.0000, 0.0000],
#         [0.0005, 0.0005, 0.0004,  ..., 0.0007, 0.0000, 0.0000],
#         [0.0005, 0.0005, 0.0006,  ..., 0.0004, 0.0000, 0.0000],
#         ...,
#         [0.0008, 0.0004, 0.0002,  ..., 0.0005, 0.0000, 0.0000],
#         [0.0004, 0.0008, 0.0002,  ..., 0.0008, 0.0000, 0.0000],
#         [0.0003, 0.0008, 0.0003,  ..., 0.0009, 0.0000, 0.0000]],
#        device='cuda:0')
# tensor([[1.6117e-04, 4.1610e-04, 7.3969e-05,  ..., 3.8417e-05, 0.0000e+00,
#          0.0000e+00],
#         [9.2042e-04, 3.7967e-04, 4.5109e-04,  ..., 4.7726e-04, 0.0000e+00,
#          0.0000e+00],
#         [3.8519e-04, 2.5382e-04, 6.3613e-05,  ..., 3.0397e-04, 0.0000e+00,
#          0.0000e+00],
#         ...,
#         [3.3920e-04, 1.4128e-04, 1.4949e-04,  ..., 8.9765e-05, 0.0000e+00,
#          0.0000e+00],
#         [2.8646e-04, 1.2641e-04, 2.9498e-04,  ..., 1.5724e-04, 0.0000e+00,
#          0.0000e+00],
#         [7.5902e-04, 1.9771e-04, 1.1605e-03,  ..., 1.6892e-03, 0.0000e+00,
#          0.0000e+00]], device='cuda:0')
# tensor([[1.6296e-04, 1.4002e-04, 9.1216e-04,  ..., 9.4812e-05, 0.0000e+00,
#          0.0000e+00],
#         [7.6881e-04, 3.2684e-05, 1.7495e-04,  ..., 7.9936e-04, 0.0000e+00,
#          0.0000e+00],
#         [4.3580e-05, 1.0747e-05, 2.0124e-04,  ..., 2.6731e-05, 0.0000e+00,
#          0.0000e+00],
#         ...,
#         [5.1055e-05, 2.9804e-04, 1.4630e-04,  ..., 1.4899e-04, 0.0000e+00,
#          0.0000e+00],
#         [1.6224e-04, 6.5772e-05, 1.1110e-04,  ..., 1.8546e-05, 0.0000e+00,
#          0.0000e+00],
#         [2.2751e-04, 4.2696e-04, 1.6631e-04,  ..., 1.8651e-04, 0.0000e+00,
#          0.0000e+00]], device='cuda:0')
# tensor([[3.6445e-04, 6.3034e-05, 1.0663e-04,  ..., 1.0682e-03, 0.0000e+00,
#          0.0000e+00],
#         [8.9135e-04, 9.2767e-04, 8.1144e-04,  ..., 1.2951e-03, 0.0000e+00,
#          0.0000e+00],
#         [2.7085e-04, 6.8074e-05, 5.1370e-04,  ..., 3.2395e-05, 0.0000e+00,
#          0.0000e+00],
#         ...,
#         [7.3863e-05, 3.5096e-04, 3.8023e-04,  ..., 8.0222e-04, 0.0000e+00,
#          0.0000e+00],
#         [2.5264e-04, 1.9608e-04, 5.8763e-05,  ..., 3.5733e-04, 0.0000e+00,
#          0.0000e+00],
#         [1.3024e-03, 9.2529e-04, 7.8557e-04,  ..., 1.1862e-03, 0.0000e+00,
#          0.0000e+00]], device='cuda:0')
# tensor([[0.0010, 0.0009, 0.0002,  ..., 0.0007, 0.0000, 0.0000],
#         [0.0014, 0.0010, 0.0004,  ..., 0.0007, 0.0000, 0.0000],
#         [0.0023, 0.0005, 0.0005,  ..., 0.0014, 0.0000, 0.0000],
#         ...,
#         [0.0010, 0.0005, 0.0001,  ..., 0.0010, 0.0000, 0.0000],
#         [0.0018, 0.0011, 0.0009,  ..., 0.0020, 0.0000, 0.0000],
#         [0.0005, 0.0003, 0.0006,  ..., 0.0002, 0.0000, 0.0000]],
#        device='cuda:0')
# tensor([[8.9573e-04, 6.1738e-04, 4.3657e-04,  ..., 5.9816e-04, 0.0000e+00,
#          0.0000e+00],
#         [7.1740e-05, 4.5578e-04, 2.7163e-04,  ..., 2.2195e-04, 0.0000e+00,
#          0.0000e+00],
#         [4.2278e-05, 6.0535e-04, 2.2969e-04,  ..., 3.9553e-04, 0.0000e+00,
#          0.0000e+00],
#         ...,
#         [1.7693e-03, 9.6828e-04, 2.8305e-05,  ..., 8.3824e-04, 0.0000e+00,
#          0.0000e+00],
#         [1.6478e-04, 4.2644e-04, 5.8711e-06,  ..., 8.6822e-05, 0.0000e+00,
#          0.0000e+00],
#         [1.1575e-04, 3.0918e-04, 3.6255e-05,  ..., 1.9651e-04, 0.0000e+00,
#          0.0000e+00]], device='cuda:0')
# tensor([[6.4827e-04, 4.1896e-04, 3.6319e-04,  ..., 3.2474e-04, 0.0000e+00,
#          0.0000e+00],
#         [7.3036e-04, 9.3941e-04, 4.9289e-04,  ..., 8.5725e-04, 0.0000e+00,
#          0.0000e+00],
#         [2.7648e-04, 7.2207e-05, 1.4316e-03,  ..., 4.0558e-04, 0.0000e+00,
#          0.0000e+00],
#         ...,
#         [1.4500e-03, 5.4085e-04, 2.9571e-05,  ..., 1.0239e-03, 0.0000e+00,
#          0.0000e+00],
#         [5.8296e-04, 3.6462e-04, 3.4411e-04,  ..., 3.7574e-04, 0.0000e+00,
#          0.0000e+00],
#         [6.4477e-04, 3.7931e-04, 4.7310e-04,  ..., 7.3611e-04, 0.0000e+00,
#          0.0000e+00]], device='cuda:0')
# tensor([[3.5399e-04, 2.3042e-04, 1.6505e-04,  ..., 3.4858e-04, 0.0000e+00,
#          0.0000e+00],
#         [4.7106e-04, 8.8615e-04, 8.2346e-04,  ..., 3.7448e-05, 0.0000e+00,
#          0.0000e+00],
#         [2.8158e-05, 3.5756e-04, 3.1441e-04,  ..., 5.3264e-05, 0.0000e+00,
#          0.0000e+00],
#         ...,
#         [4.4236e-04, 3.2298e-05, 2.9965e-04,  ..., 2.5272e-04, 0.0000e+00,
#          0.0000e+00],
#         [3.1713e-04, 2.6350e-04, 4.7758e-06,  ..., 2.1643e-04, 0.0000e+00,
#          0.0000e+00],
#         [1.3935e-03, 1.2744e-03, 9.1456e-05,  ..., 7.3959e-04, 0.0000e+00,
#          0.0000e+00]], device='cuda:0')
# tensor([[3.6468e-04, 1.8169e-04, 2.4029e-04,  ..., 3.3297e-04, 0.0000e+00,
#          0.0000e+00],
#         [3.9013e-04, 2.9852e-04, 7.3088e-04,  ..., 2.6703e-04, 0.0000e+00,
#          0.0000e+00],
#         [9.9226e-04, 3.6583e-04, 1.2662e-04,  ..., 4.2487e-04, 0.0000e+00,
#          0.0000e+00],
#         ...,
#         [1.4107e-04, 1.1220e-03, 3.7372e-04,  ..., 3.3245e-04, 0.0000e+00,
#          0.0000e+00],
#         [1.3549e-03, 7.6946e-04, 2.8323e-04,  ..., 1.0646e-03, 0.0000e+00,
#          0.0000e+00],
#         [2.2233e-03, 4.0371e-05, 1.3333e-04,  ..., 2.0232e-03, 0.0000e+00,
#          0.0000e+00]], device='cuda:0')
# tensor([[1.0913e-03, 4.5481e-04, 4.9939e-04,  ..., 5.8091e-04, 0.0000e+00,
#          0.0000e+00],
#         [7.1909e-04, 3.9309e-04, 1.2900e-04,  ..., 1.1902e-04, 0.0000e+00,
#          0.0000e+00],
#         [2.1587e-04, 6.4205e-04, 6.4842e-05,  ..., 4.5959e-04, 0.0000e+00,
#          0.0000e+00],
#         ...,
#         [1.5149e-04, 3.1967e-04, 9.4190e-05,  ..., 4.1112e-04, 0.0000e+00,
#          0.0000e+00],
#         [1.3227e-04, 8.2567e-05, 4.3672e-04,  ..., 1.0540e-04, 0.0000e+00,
#          0.0000e+00],
#         [9.0909e-04, 6.2250e-04, 6.4032e-04,  ..., 1.0188e-03, 0.0000e+00,
#          0.0000e+00]], device='cuda:0', grad_fn=<AbsBackward>)
#   0%|          | 0/13 [00:00<?, ?it/s]
# tensor([[4.1348e-03, 2.1150e-03, 3.9018e-04,  ..., 3.5526e-04, 0.0000e+00,
#          0.0000e+00],
#         [8.6233e-04, 1.7546e-03, 1.7159e-04,  ..., 7.3641e-04, 0.0000e+00,
#          0.0000e+00],
#         [1.0061e-03, 5.3574e-04, 1.6806e-04,  ..., 8.7760e-04, 0.0000e+00,
#          0.0000e+00],
#         ...,
#         [1.8384e-03, 3.8174e-03, 7.0805e-04,  ..., 1.2051e-03, 0.0000e+00,
#          0.0000e+00],
#         [1.2133e-03, 3.2898e-05, 5.4016e-04,  ..., 1.0004e-03, 0.0000e+00,
#          0.0000e+00],
#         [1.7153e-03, 3.9558e-03, 3.1509e-05,  ..., 1.2834e-03, 0.0000e+00,
#          0.0000e+00]], device='cuda:0')
# tensor([[1.9033e-03, 2.7664e-03, 5.4276e-04,  ..., 3.0081e-03, 0.0000e+00,
#          0.0000e+00],
#         [2.7747e-03, 2.0220e-03, 4.4705e-04,  ..., 1.7133e-03, 0.0000e+00,
#          0.0000e+00],
#         [1.3933e-03, 2.8660e-03, 8.6606e-04,  ..., 3.8926e-03, 0.0000e+00,
#          0.0000e+00],
#         ...,
#         [4.8005e-04, 1.3369e-04, 1.7926e-03,  ..., 4.7011e-04, 0.0000e+00,
#          0.0000e+00],
#         [7.0680e-04, 3.0236e-04, 4.0129e-05,  ..., 5.1942e-04, 0.0000e+00,
#          0.0000e+00],
#         [2.4857e-04, 6.2455e-04, 1.5520e-04,  ..., 1.1472e-03, 0.0000e+00,
#          0.0000e+00]], device='cuda:0')
# tensor([[0.0002, 0.0002, 0.0008,  ..., 0.0010, 0.0000, 0.0000],
#         [0.0025, 0.0028, 0.0025,  ..., 0.0007, 0.0000, 0.0000],
#         [0.0034, 0.0024, 0.0020,  ..., 0.0019, 0.0000, 0.0000],
#         ...,
#         [0.0015, 0.0018, 0.0005,  ..., 0.0028, 0.0000, 0.0000],
#         [0.0042, 0.0011, 0.0003,  ..., 0.0028, 0.0000, 0.0000],
#         [0.0012, 0.0004, 0.0004,  ..., 0.0013, 0.0000, 0.0000]],
#        device='cuda:0')
# tensor([[0.0002, 0.0011, 0.0003,  ..., 0.0002, 0.0000, 0.0000],
#         [0.0020, 0.0018, 0.0011,  ..., 0.0020, 0.0000, 0.0000],
#         [0.0015, 0.0022, 0.0019,  ..., 0.0015, 0.0000, 0.0000],
#         ...,
#         [0.0017, 0.0003, 0.0002,  ..., 0.0004, 0.0000, 0.0000],
#         [0.0034, 0.0008, 0.0001,  ..., 0.0021, 0.0000, 0.0000],
#         [0.0017, 0.0008, 0.0001,  ..., 0.0007, 0.0000, 0.0000]],
#        device='cuda:0')
# tensor([[0.0017, 0.0007, 0.0004,  ..., 0.0010, 0.0000, 0.0000],
#         [0.0013, 0.0009, 0.0006,  ..., 0.0019, 0.0000, 0.0000],
#         [0.0011, 0.0013, 0.0006,  ..., 0.0017, 0.0000, 0.0000],
#         ...,
#         [0.0010, 0.0002, 0.0001,  ..., 0.0006, 0.0000, 0.0000],
#         [0.0002, 0.0015, 0.0006,  ..., 0.0011, 0.0000, 0.0000],
#         [0.0004, 0.0016, 0.0006,  ..., 0.0016, 0.0000, 0.0000]],
#        device='cuda:0')
# tensor([[1.2577e-03, 1.3235e-03, 1.5073e-05,  ..., 4.7015e-04, 0.0000e+00,
#          0.0000e+00],
#         [8.2659e-04, 4.1869e-04, 1.2379e-03,  ..., 1.4694e-03, 0.0000e+00,
#          0.0000e+00],
#         [6.7838e-04, 3.0710e-04, 3.8676e-04,  ..., 5.4802e-04, 0.0000e+00,
#          0.0000e+00],
#         ...,
#         [3.5912e-05, 7.3151e-04, 1.2784e-04,  ..., 4.7311e-07, 0.0000e+00,
#          0.0000e+00],
#         [3.6350e-04, 3.6565e-04, 2.7158e-04,  ..., 2.9378e-04, 0.0000e+00,
#          0.0000e+00],
#         [5.0848e-03, 2.2138e-03, 1.0662e-03,  ..., 2.9861e-03, 0.0000e+00,
#          0.0000e+00]], device='cuda:0')
# tensor([[2.7733e-03, 1.8819e-03, 2.2651e-03,  ..., 8.0132e-04, 0.0000e+00,
#          0.0000e+00],
#         [4.7889e-03, 6.7982e-04, 8.1807e-04,  ..., 6.7706e-04, 0.0000e+00,
#          0.0000e+00],
#         [1.0159e-03, 5.6546e-04, 3.7718e-04,  ..., 2.3706e-04, 0.0000e+00,
#          0.0000e+00],
#         ...,
#         [9.6773e-04, 1.0383e-03, 4.2167e-04,  ..., 6.5543e-04, 0.0000e+00,
#          0.0000e+00],
#         [5.7004e-05, 4.8199e-04, 5.8667e-04,  ..., 1.8089e-04, 0.0000e+00,
#          0.0000e+00],
#         [1.6223e-03, 1.4837e-03, 5.7220e-06,  ..., 7.5509e-04, 0.0000e+00,
#          0.0000e+00]], device='cuda:0')
# tensor([[5.0304e-03, 1.4739e-03, 8.2130e-04,  ..., 1.7287e-03, 0.0000e+00,
#          0.0000e+00],
#         [3.8118e-03, 3.1120e-03, 1.8999e-03,  ..., 2.3253e-03, 0.0000e+00,
#          0.0000e+00],
#         [6.2626e-04, 5.5616e-04, 1.5080e-03,  ..., 5.1150e-04, 0.0000e+00,
#          0.0000e+00],
#         ...,
#         [7.8000e-05, 1.4563e-04, 4.7590e-04,  ..., 8.2109e-04, 0.0000e+00,
#          0.0000e+00],
#         [6.2774e-04, 6.9181e-04, 1.6517e-04,  ..., 7.2964e-04, 0.0000e+00,
#          0.0000e+00],
#         [2.7654e-03, 1.2571e-03, 1.0508e-04,  ..., 1.8342e-03, 0.0000e+00,
#          0.0000e+00]], device='cuda:0')
# tensor([[1.0093e-03, 2.4072e-03, 3.8274e-04,  ..., 2.2177e-03, 0.0000e+00,
#          0.0000e+00],
#         [2.2398e-03, 1.4074e-03, 2.6375e-06,  ..., 2.6523e-03, 0.0000e+00,
#          0.0000e+00],
#         [3.8288e-03, 1.0485e-03, 1.2740e-03,  ..., 2.4924e-03, 0.0000e+00,
#          0.0000e+00],
#         ...,
#         [4.4731e-04, 9.5087e-04, 1.0534e-04,  ..., 2.4793e-03, 0.0000e+00,
#          0.0000e+00],
#         [4.7719e-03, 2.3961e-03, 1.4572e-03,  ..., 2.9642e-03, 0.0000e+00,
#          0.0000e+00],
#         [4.9354e-04, 3.2900e-04, 1.3821e-04,  ..., 1.5430e-03, 0.0000e+00,
#          0.0000e+00]], device='cuda:0')
# tensor([[1.7794e-04, 7.7624e-04, 2.5778e-04,  ..., 2.0914e-03, 0.0000e+00,
#          0.0000e+00],
#         [2.5201e-03, 6.0305e-04, 4.5168e-04,  ..., 9.6493e-04, 0.0000e+00,
#          0.0000e+00],
#         [1.3992e-03, 1.4111e-03, 1.6692e-04,  ..., 1.5045e-03, 0.0000e+00,
#          0.0000e+00],
#         ...,
#         [1.9414e-03, 9.1072e-04, 7.1727e-04,  ..., 1.6817e-03, 0.0000e+00,
#          0.0000e+00],
#         [3.4431e-05, 9.2536e-04, 3.8431e-04,  ..., 5.4507e-04, 0.0000e+00,
#          0.0000e+00],
#         [1.9817e-05, 1.1813e-04, 2.4495e-04,  ..., 3.8941e-04, 0.0000e+00,
#          0.0000e+00]], device='cuda:0')
# tensor([[0.0026, 0.0007, 0.0009,  ..., 0.0005, 0.0000, 0.0000],
#         [0.0021, 0.0011, 0.0016,  ..., 0.0020, 0.0000, 0.0000],
#         [0.0019, 0.0024, 0.0037,  ..., 0.0030, 0.0000, 0.0000],
#         ...,
#         [0.0012, 0.0018, 0.0010,  ..., 0.0009, 0.0000, 0.0000],
#         [0.0003, 0.0005, 0.0011,  ..., 0.0014, 0.0000, 0.0000],
#         [0.0006, 0.0007, 0.0003,  ..., 0.0015, 0.0000, 0.0000]],
#        device='cuda:0')
# tensor([[2.1336e-03, 6.4161e-04, 5.1535e-04,  ..., 8.3259e-04, 0.0000e+00,
#          0.0000e+00],
#         [4.2287e-03, 2.0824e-03, 9.5279e-04,  ..., 6.3132e-04, 0.0000e+00,
#          0.0000e+00],
#         [3.4352e-04, 3.8853e-04, 1.4387e-04,  ..., 3.0696e-05, 0.0000e+00,
#          0.0000e+00],
#         ...,
#         [1.4992e-04, 2.1681e-04, 2.1766e-04,  ..., 5.1826e-04, 0.0000e+00,
#          0.0000e+00],
#         [2.2721e-04, 8.2677e-04, 8.6904e-05,  ..., 1.1935e-03, 0.0000e+00,
#          0.0000e+00],
#         [4.1903e-03, 2.2413e-03, 1.2555e-03,  ..., 1.6410e-03, 0.0000e+00,
#          0.0000e+00]], device='cuda:0')
# tensor([[1.2505e-03, 6.5596e-04, 1.8149e-04,  ..., 6.4828e-05, 0.0000e+00,
#          0.0000e+00],
#         [2.4915e-04, 8.0898e-05, 1.4672e-03,  ..., 3.9118e-04, 0.0000e+00,
#          0.0000e+00],
#         [2.2359e-03, 1.0354e-04, 1.2328e-03,  ..., 9.5018e-04, 0.0000e+00,
#          0.0000e+00],
#         ...,
#         [9.3469e-04, 2.8607e-03, 1.0982e-04,  ..., 7.3408e-04, 0.0000e+00,
#          0.0000e+00],
#         [2.1967e-03, 2.5795e-03, 8.3887e-04,  ..., 1.7335e-03, 0.0000e+00,
#          0.0000e+00],
#         [5.1719e-03, 2.3248e-04, 7.4162e-04,  ..., 3.6331e-03, 0.0000e+00,
#          0.0000e+00]], device='cuda:0')
# tensor([[2.5398e-03, 3.4197e-03, 1.1775e-03,  ..., 4.7084e-05, 0.0000e+00,
#          6.8531e-04],
#         [3.1691e-04, 4.5419e-05, 2.9775e-04,  ..., 1.4924e-03, 0.0000e+00,
#          0.0000e+00],
#         [9.3599e-04, 1.2701e-03, 4.7233e-04,  ..., 8.2923e-04, 0.0000e+00,
#          0.0000e+00],
#         ...,
#         [1.5940e-03, 4.5823e-04, 8.8970e-04,  ..., 1.2089e-04, 0.0000e+00,
#          0.0000e+00],
#         [1.5885e-03, 8.7470e-06, 8.0571e-05,  ..., 6.4699e-04, 0.0000e+00,
#          0.0000e+00],
#         [1.6034e-03, 2.5049e-03, 9.5487e-04,  ..., 4.9365e-04, 0.0000e+00,
#          0.0000e+00]], device='cuda:0', grad_fn=<AbsBackward>)
#   0%|          | 0/13 [00:00<?, ?it/s]
# tensor([[9.6869e-03, 1.3846e-02, 3.6033e-03,  ..., 1.2950e-03, 2.9855e-03,
#          1.4153e-02],
#         [3.2041e-03, 1.1553e-02, 8.8621e-04,  ..., 1.3374e-03, 1.8626e-03,
#          7.2978e-03],
#         [2.7557e-03, 3.5607e-03, 3.9060e-04,  ..., 7.6776e-04, 7.9619e-05,
#          2.9370e-03],
#         ...,
#         [5.9672e-03, 1.3485e-02, 2.2248e-03,  ..., 5.7163e-04, 2.6625e-03,
#          9.8129e-03],
#         [1.9540e-03, 1.6252e-03, 2.0923e-04,  ..., 8.7095e-04, 6.9759e-04,
#          1.0185e-03],
#         [7.2720e-03, 1.5949e-02, 1.6401e-03,  ..., 6.8119e-04, 3.6387e-03,
#          1.1428e-02]], device='cuda:0')
# tensor([[6.8787e-03, 1.4718e-02, 1.6016e-03,  ..., 4.0116e-03, 3.0113e-03,
#          1.0835e-02],
#         [7.6399e-03, 1.1345e-02, 1.7540e-03,  ..., 2.8475e-03, 2.7387e-03,
#          1.0010e-02],
#         [5.4083e-03, 1.2038e-02, 2.3262e-03,  ..., 3.8678e-03, 1.0754e-03,
#          8.4534e-03],
#         ...,
#         [7.5483e-04, 3.6959e-04, 3.4063e-03,  ..., 3.7783e-04, 6.1074e-04,
#          5.3146e-04],
#         [1.6931e-03, 5.3605e-03, 1.5340e-03,  ..., 1.2496e-03, 7.8484e-04,
#          4.6149e-03],
#         [5.7291e-05, 9.6020e-04, 1.4168e-03,  ..., 1.5102e-04, 5.1990e-04,
#          2.3564e-04]], device='cuda:0')
# tensor([[2.5455e-05, 8.0966e-04, 1.1123e-03,  ..., 7.5082e-04, 4.0573e-04,
#          9.2746e-04],
#         [8.7687e-03, 1.4491e-02, 2.7481e-04,  ..., 1.7835e-03, 5.5909e-03,
#          1.6394e-02],
#         [1.0155e-02, 1.4449e-02, 1.3101e-03,  ..., 3.9533e-03, 4.8752e-03,
#          1.6624e-02],
#         ...,
#         [3.3856e-03, 5.5225e-03, 1.7538e-04,  ..., 3.2334e-03, 7.2055e-04,
#          3.2253e-03],
#         [7.6150e-03, 8.5666e-03, 1.8615e-03,  ..., 2.9441e-03, 1.6439e-03,
#          4.1255e-03],
#         [4.2807e-03, 4.0382e-03, 2.1187e-03,  ..., 2.6194e-03, 6.1294e-04,
#          2.7741e-03]], device='cuda:0')
# tensor([[2.7856e-03, 9.2885e-03, 7.0977e-04,  ..., 2.1451e-03, 3.7565e-03,
#          9.6021e-03],
#         [3.6404e-03, 8.4193e-03, 1.1320e-03,  ..., 1.2733e-03, 4.1198e-04,
#          3.9013e-03],
#         [3.6217e-03, 9.1671e-03, 3.7566e-05,  ..., 1.7857e-03, 1.4538e-03,
#          5.3996e-03],
#         ...,
#         [1.4465e-03, 9.6231e-04, 9.4941e-04,  ..., 2.2643e-04, 7.0015e-04,
#          1.2806e-03],
#         [5.2535e-03, 2.7752e-03, 2.0016e-04,  ..., 3.5825e-03, 9.8177e-05,
#          1.6566e-03],
#         [6.1274e-03, 8.4744e-03, 1.3925e-03,  ..., 1.3787e-05, 3.0981e-03,
#          9.8165e-03]], device='cuda:0')
# tensor([[4.2169e-03, 9.9468e-03, 5.5283e-04,  ..., 1.2017e-03, 3.3761e-03,
#          7.6365e-03],
#         [2.2736e-03, 2.9762e-03, 5.0186e-04,  ..., 1.7561e-03, 1.8388e-04,
#          1.2845e-03],
#         [2.2639e-03, 4.0520e-03, 4.5295e-04,  ..., 1.6057e-03, 3.6717e-04,
#          1.0770e-03],
#         ...,
#         [1.8279e-03, 2.2084e-03, 9.2367e-04,  ..., 3.8164e-04, 5.4643e-04,
#          2.4836e-03],
#         [6.2003e-04, 3.5255e-03, 3.2154e-04,  ..., 6.2443e-04, 8.3746e-04,
#          2.2159e-03],
#         [1.6229e-03, 4.1130e-03, 5.3234e-05,  ..., 1.2764e-03, 4.9116e-04,
#          2.8128e-03]], device='cuda:0')
# tensor([[6.0730e-04, 6.8203e-03, 1.0073e-03,  ..., 2.1800e-03, 1.6866e-03,
#          3.2479e-03],
#         [1.4594e-03, 3.3938e-03, 1.0056e-04,  ..., 1.3224e-03, 4.3195e-05,
#          1.6830e-03],
#         [1.1548e-03, 3.6537e-03, 4.5246e-04,  ..., 6.6465e-04, 7.6695e-04,
#          1.8076e-03],
#         ...,
#         [1.8468e-03, 5.2650e-03, 1.0643e-03,  ..., 4.8415e-04, 8.3366e-04,
#          2.2432e-03],
#         [1.0961e-03, 2.0814e-04, 1.0884e-03,  ..., 1.0277e-03, 4.5584e-04,
#          1.4282e-04],
#         [1.3518e-02, 1.3097e-02, 3.0071e-03,  ..., 2.9857e-03, 5.9561e-03,
#          1.9800e-02]], device='cuda:0')
# tensor([[8.9886e-03, 9.2922e-03, 1.2448e-03,  ..., 5.9119e-04, 1.8131e-03,
#          1.2150e-02],
#         [9.4565e-03, 3.4259e-03, 2.2655e-03,  ..., 3.0530e-03, 5.4562e-04,
#          1.2645e-02],
#         [2.2155e-04, 1.3346e-03, 1.0020e-04,  ..., 9.5721e-05, 5.8527e-04,
#          4.5770e-04],
#         ...,
#         [4.7928e-04, 4.7283e-03, 1.3046e-03,  ..., 1.7494e-03, 6.4759e-04,
#          1.4217e-03],
#         [2.3180e-03, 2.9994e-03, 2.1166e-04,  ..., 4.6597e-04, 9.3471e-04,
#          2.2688e-03],
#         [8.1312e-04, 6.0411e-03, 9.4428e-04,  ..., 1.9339e-04, 1.1192e-03,
#          1.9613e-03]], device='cuda:0')
# tensor([[1.1744e-02, 8.7963e-03, 1.7039e-03,  ..., 4.2735e-03, 1.7932e-03,
#          1.2481e-02],
#         [9.7873e-03, 1.6247e-02, 1.5485e-03,  ..., 2.7366e-03, 3.7969e-03,
#          1.5604e-02],
#         [4.5214e-04, 1.1568e-03, 5.4123e-04,  ..., 2.0191e-04, 4.3451e-04,
#          8.1040e-04],
#         ...,
#         [2.2617e-03, 4.3838e-03, 4.2967e-05,  ..., 1.4565e-03, 9.7854e-04,
#          2.1809e-03],
#         [6.1864e-04, 2.1347e-03, 6.6520e-04,  ..., 3.2941e-04, 8.0321e-04,
#          2.7328e-04],
#         [5.9242e-03, 7.1443e-03, 1.2825e-03,  ..., 3.1904e-03, 2.9757e-04,
#          4.0530e-03]], device='cuda:0')
# tensor([[0.0005, 0.0049, 0.0004,  ..., 0.0002, 0.0011, 0.0012],
#         [0.0036, 0.0050, 0.0010,  ..., 0.0030, 0.0015, 0.0018],
#         [0.0096, 0.0112, 0.0006,  ..., 0.0029, 0.0024, 0.0123],
#         ...,
#         [0.0022, 0.0045, 0.0006,  ..., 0.0025, 0.0007, 0.0032],
#         [0.0108, 0.0155, 0.0021,  ..., 0.0028, 0.0046, 0.0176],
#         [0.0007, 0.0018, 0.0003,  ..., 0.0007, 0.0005, 0.0014]],
#        device='cuda:0')
# tensor([[3.9291e-04, 4.1446e-03, 2.5453e-04,  ..., 1.6947e-03, 6.9717e-04,
#          1.7938e-03],
#         [3.6467e-03, 2.0847e-04, 1.4857e-04,  ..., 2.2460e-03, 3.6164e-04,
#          2.7834e-03],
#         [4.3309e-03, 7.7252e-03, 1.6456e-03,  ..., 2.0672e-03, 2.7380e-04,
#          5.1581e-03],
#         ...,
#         [3.1569e-03, 4.3743e-03, 1.5954e-03,  ..., 1.6125e-03, 9.4008e-04,
#          3.5454e-03],
#         [3.1006e-05, 2.6090e-03, 1.6320e-04,  ..., 3.4733e-04, 9.0918e-04,
#          1.0005e-03],
#         [8.1479e-04, 1.6057e-04, 1.4247e-03,  ..., 4.3634e-04, 4.4536e-04,
#          4.0106e-04]], device='cuda:0')
# tensor([[5.8164e-03, 6.9915e-03, 1.3473e-03,  ..., 7.7193e-04, 9.2051e-04,
#          3.3913e-03],
#         [4.5406e-03, 5.6591e-03, 7.1758e-04,  ..., 1.7269e-03, 5.6571e-04,
#          1.7520e-03],
#         [6.2310e-03, 6.2213e-03, 1.2239e-03,  ..., 1.7758e-05, 5.0882e-03,
#          1.0479e-02],
#         ...,
#         [3.2739e-03, 9.3565e-03, 1.5780e-03,  ..., 5.8087e-04, 8.6533e-04,
#          6.3751e-03],
#         [8.9787e-04, 3.5427e-03, 2.3939e-03,  ..., 3.2849e-03, 2.0905e-03,
#          4.0467e-03],
#         [5.1204e-04, 3.4293e-04, 1.3907e-03,  ..., 6.0819e-04, 6.0593e-04,
#          7.5790e-04]], device='cuda:0')
# tensor([[5.2321e-03, 4.3304e-03, 1.2291e-03,  ..., 2.3509e-03, 4.7499e-04,
#          2.8592e-03],
#         [9.9818e-03, 8.2458e-03, 3.1879e-03,  ..., 2.7432e-03, 5.5415e-03,
#          1.4612e-02],
#         [4.9602e-05, 1.9865e-03, 1.7999e-03,  ..., 2.2744e-04, 1.0422e-03,
#          3.1847e-04],
#         ...,
#         [8.6799e-04, 1.9975e-04, 2.8903e-04,  ..., 7.0821e-05, 1.4686e-04,
#          1.2115e-04],
#         [9.7267e-06, 7.3512e-04, 3.2266e-04,  ..., 1.1237e-03, 5.8450e-04,
#          7.7716e-04],
#         [7.9824e-03, 9.9227e-03, 7.4804e-05,  ..., 1.9856e-03, 1.6142e-03,
#          9.3350e-03]], device='cuda:0')
# tensor([[0.0001, 0.0054, 0.0003,  ..., 0.0002, 0.0006, 0.0017],
#         [0.0007, 0.0006, 0.0025,  ..., 0.0003, 0.0004, 0.0007],
#         [0.0038, 0.0052, 0.0018,  ..., 0.0014, 0.0003, 0.0042],
#         ...,
#         [0.0015, 0.0073, 0.0028,  ..., 0.0026, 0.0025, 0.0028],
#         [0.0058, 0.0117, 0.0001,  ..., 0.0024, 0.0035, 0.0088],
#         [0.0108, 0.0091, 0.0005,  ..., 0.0043, 0.0027, 0.0127]],
#        device='cuda:0')
# tensor([[1.4676e-02, 1.8772e-02, 2.5893e-03,  ..., 4.3340e-03, 8.5197e-03,
#          2.6794e-02],
#         [1.6009e-03, 2.4672e-03, 1.3420e-03,  ..., 5.4092e-04, 2.4229e-04,
#          2.3918e-03],
#         [9.8663e-04, 2.7840e-03, 3.9060e-04,  ..., 7.3861e-04, 1.4305e-04,
#          1.4415e-03],
#         ...,
#         [6.5840e-03, 1.8971e-02, 1.6220e-03,  ..., 9.6057e-05, 4.5383e-03,
#          1.5753e-02],
#         [5.9897e-03, 7.8913e-03, 3.8926e-04,  ..., 2.5955e-03, 1.4193e-03,
#          5.0700e-03],
#         [4.2684e-05, 5.7126e-03, 1.3450e-04,  ..., 1.8410e-03, 7.6207e-04,
#          2.3783e-03]], device='cuda:0', grad_fn=<AbsBackward>)
#   0%|          | 0/13 [00:00<?, ?it/s]
# tensor([[0.0051, 0.0204, 0.0258,  ..., 0.0034, 0.0433, 0.0952],
#         [0.0073, 0.0205, 0.0095,  ..., 0.0086, 0.0371, 0.0743],
#         [0.0114, 0.0166, 0.0057,  ..., 0.0058, 0.0138, 0.0426],
#         ...,
#         [0.0009, 0.0104, 0.0133,  ..., 0.0066, 0.0428, 0.0761],
#         [0.0030, 0.0080, 0.0020,  ..., 0.0003, 0.0112, 0.0190],
#         [0.0025, 0.0165, 0.0156,  ..., 0.0100, 0.0480, 0.1004]],
#        device='cuda:0')
# tensor([[7.4252e-03, 2.2113e-02, 2.2311e-02,  ..., 6.0178e-03, 4.5660e-02,
#          9.7208e-02],
#         [5.4421e-03, 1.1794e-02, 2.1084e-02,  ..., 3.5981e-03, 3.7955e-02,
#          7.4674e-02],
#         [1.3810e-02, 2.8013e-02, 2.0967e-02,  ..., 5.8803e-03, 4.7495e-02,
#          1.0725e-01],
#         ...,
#         [3.9542e-04, 4.3479e-04, 1.1912e-04,  ..., 1.4632e-03, 5.9509e-03,
#          1.1932e-03],
#         [6.1435e-04, 9.8496e-05, 6.5853e-03,  ..., 3.6895e-03, 1.7223e-02,
#          3.2694e-02],
#         [2.0147e-03, 3.6152e-04, 1.6131e-03,  ..., 1.0335e-03, 1.8149e-03,
#          5.0785e-03]], device='cuda:0')
# tensor([[0.0021, 0.0031, 0.0010,  ..., 0.0015, 0.0045, 0.0048],
#         [0.0080, 0.0194, 0.0256,  ..., 0.0078, 0.0544, 0.1097],
#         [0.0166, 0.0274, 0.0283,  ..., 0.0098, 0.0580, 0.1322],
#         ...,
#         [0.0149, 0.0248, 0.0090,  ..., 0.0049, 0.0290, 0.0699],
#         [0.0132, 0.0268, 0.0177,  ..., 0.0033, 0.0358, 0.0952],
#         [0.0138, 0.0218, 0.0127,  ..., 0.0037, 0.0214, 0.0561]],
#        device='cuda:0')
# tensor([[0.0027, 0.0034, 0.0106,  ..., 0.0024, 0.0292, 0.0334],
#         [0.0095, 0.0198, 0.0085,  ..., 0.0036, 0.0226, 0.0562],
#         [0.0044, 0.0130, 0.0077,  ..., 0.0018, 0.0214, 0.0488],
#         ...,
#         [0.0010, 0.0019, 0.0013,  ..., 0.0012, 0.0062, 0.0159],
#         [0.0133, 0.0093, 0.0072,  ..., 0.0050, 0.0179, 0.0585],
#         [0.0033, 0.0009, 0.0146,  ..., 0.0013, 0.0238, 0.0468]],
#        device='cuda:0')
# tensor([[0.0003, 0.0038, 0.0166,  ..., 0.0013, 0.0273, 0.0497],
#         [0.0058, 0.0129, 0.0046,  ..., 0.0041, 0.0157, 0.0401],
#         [0.0055, 0.0130, 0.0056,  ..., 0.0040, 0.0163, 0.0399],
#         ...,
#         [0.0058, 0.0163, 0.0036,  ..., 0.0042, 0.0151, 0.0293],
#         [0.0043, 0.0178, 0.0047,  ..., 0.0049, 0.0151, 0.0281],
#         [0.0082, 0.0181, 0.0049,  ..., 0.0054, 0.0141, 0.0367]],
#        device='cuda:0')
# tensor([[0.0011, 0.0071, 0.0030,  ..., 0.0045, 0.0142, 0.0278],
#         [0.0074, 0.0154, 0.0048,  ..., 0.0037, 0.0147, 0.0410],
#         [0.0052, 0.0103, 0.0029,  ..., 0.0035, 0.0100, 0.0307],
#         ...,
#         [0.0047, 0.0136, 0.0067,  ..., 0.0037, 0.0119, 0.0372],
#         [0.0026, 0.0005, 0.0017,  ..., 0.0007, 0.0029, 0.0131],
#         [0.0009, 0.0067, 0.0314,  ..., 0.0024, 0.0501, 0.1044]],
#        device='cuda:0')
# tensor([[0.0011, 0.0038, 0.0165,  ..., 0.0026, 0.0218, 0.0656],
#         [0.0008, 0.0047, 0.0137,  ..., 0.0046, 0.0157, 0.0645],
#         [0.0027, 0.0052, 0.0030,  ..., 0.0014, 0.0039, 0.0194],
#         ...,
#         [0.0006, 0.0063, 0.0019,  ..., 0.0017, 0.0052, 0.0131],
#         [0.0042, 0.0074, 0.0056,  ..., 0.0023, 0.0092, 0.0316],
#         [0.0041, 0.0155, 0.0064,  ..., 0.0044, 0.0145, 0.0346]],
#        device='cuda:0')
# tensor([[0.0151, 0.0143, 0.0182,  ..., 0.0102, 0.0314, 0.1109],
#         [0.0041, 0.0133, 0.0224,  ..., 0.0054, 0.0464, 0.1013],
#         [0.0055, 0.0086, 0.0014,  ..., 0.0006, 0.0057, 0.0092],
#         ...,
#         [0.0033, 0.0038, 0.0042,  ..., 0.0013, 0.0059, 0.0326],
#         [0.0018, 0.0036, 0.0003,  ..., 0.0016, 0.0015, 0.0103],
#         [0.0159, 0.0252, 0.0144,  ..., 0.0050, 0.0298, 0.0761]],
#        device='cuda:0')
# tensor([[0.0049, 0.0196, 0.0028,  ..., 0.0033, 0.0222, 0.0323],
#         [0.0114, 0.0237, 0.0097,  ..., 0.0058, 0.0267, 0.0620],
#         [0.0065, 0.0219, 0.0205,  ..., 0.0074, 0.0448, 0.1093],
#         ...,
#         [0.0143, 0.0247, 0.0061,  ..., 0.0077, 0.0262, 0.0619],
#         [0.0037, 0.0152, 0.0255,  ..., 0.0073, 0.0557, 0.1167],
#         [0.0027, 0.0062, 0.0026,  ..., 0.0007, 0.0092, 0.0170]],
#        device='cuda:0')
# tensor([[0.0108, 0.0215, 0.0046,  ..., 0.0061, 0.0162, 0.0410],
#         [0.0053, 0.0011, 0.0054,  ..., 0.0016, 0.0050, 0.0220],
#         [0.0151, 0.0224, 0.0100,  ..., 0.0064, 0.0196, 0.0631],
#         ...,
#         [0.0061, 0.0189, 0.0065,  ..., 0.0044, 0.0270, 0.0503],
#         [0.0009, 0.0060, 0.0046,  ..., 0.0017, 0.0092, 0.0195],
#         [0.0021, 0.0001, 0.0005,  ..., 0.0012, 0.0002, 0.0035]],
#        device='cuda:0')
# tensor([[0.0069, 0.0100, 0.0132,  ..., 0.0048, 0.0215, 0.0437],
#         [0.0105, 0.0200, 0.0069,  ..., 0.0030, 0.0254, 0.0634],
#         [0.0004, 0.0022, 0.0237,  ..., 0.0139, 0.0133, 0.0273],
#         ...,
#         [0.0009, 0.0126, 0.0154,  ..., 0.0048, 0.0297, 0.0614],
#         [0.0002, 0.0019, 0.0022,  ..., 0.0041, 0.0070, 0.0156],
#         [0.0024, 0.0038, 0.0008,  ..., 0.0025, 0.0048, 0.0089]],
#        device='cuda:0')
# tensor([[0.0023, 0.0035, 0.0053,  ..., 0.0012, 0.0061, 0.0252],
#         [0.0014, 0.0021, 0.0179,  ..., 0.0035, 0.0277, 0.0447],
#         [0.0015, 0.0059, 0.0004,  ..., 0.0013, 0.0047, 0.0054],
#         ...,
#         [0.0006, 0.0021, 0.0008,  ..., 0.0004, 0.0019, 0.0043],
#         [0.0027, 0.0066, 0.0036,  ..., 0.0016, 0.0066, 0.0089],
#         [0.0070, 0.0172, 0.0136,  ..., 0.0046, 0.0366, 0.0754]],
#        device='cuda:0')
# tensor([[0.0006, 0.0089, 0.0008,  ..., 0.0037, 0.0057, 0.0232],
#         [0.0006, 0.0002, 0.0027,  ..., 0.0033, 0.0041, 0.0034],
#         [0.0005, 0.0057, 0.0058,  ..., 0.0026, 0.0183, 0.0402],
#         ...,
#         [0.0027, 0.0018, 0.0121,  ..., 0.0049, 0.0133, 0.0013],
#         [0.0019, 0.0054, 0.0165,  ..., 0.0016, 0.0360, 0.0593],
#         [0.0118, 0.0191, 0.0215,  ..., 0.0080, 0.0438, 0.1161]],
#        device='cuda:0')
# tensor([[0.0138, 0.0244, 0.0096,  ..., 0.0043, 0.0183, 0.0563],
#         [0.0011, 0.0009, 0.0012,  ..., 0.0004, 0.0002, 0.0047],
#         [0.0005, 0.0010, 0.0025,  ..., 0.0015, 0.0009, 0.0099],
#         ...,
#         [0.0019, 0.0025, 0.0109,  ..., 0.0029, 0.0183, 0.0515],
#         [0.0018, 0.0013, 0.0012,  ..., 0.0009, 0.0033, 0.0094],
#         [0.0089, 0.0078, 0.0026,  ..., 0.0006, 0.0117, 0.0392]],
#        device='cuda:0', grad_fn=<AbsBackward>)
#   0%|          | 0/13 [00:00<?, ?it/s]
# tensor([[0.0249, 0.0000, 0.1182,  ..., 0.0189, 0.1812, 0.3379],
#         [0.0192, 0.0000, 0.0793,  ..., 0.0086, 0.1973, 0.3307],
#         [0.0079, 0.0000, 0.0572,  ..., 0.0055, 0.0960, 0.2022],
#         ...,
#         [0.0283, 0.0000, 0.1233,  ..., 0.0058, 0.2394, 0.4560],
#         [0.0082, 0.0000, 0.0477,  ..., 0.0137, 0.0833, 0.1484],
#         [0.0298, 0.0000, 0.1117,  ..., 0.0098, 0.2401, 0.4805]],
#        device='cuda:0')
# tensor([[0.0309, 0.0000, 0.1506,  ..., 0.0082, 0.2289, 0.4529],
#         [0.0236, 0.0000, 0.1316,  ..., 0.0125, 0.1596, 0.3353],
#         [0.0335, 0.0000, 0.1804,  ..., 0.0059, 0.3150, 0.5996],
#         ...,
#         [0.0031, 0.0000, 0.0079,  ..., 0.0024, 0.0372, 0.0292],
#         [0.0080, 0.0000, 0.0403,  ..., 0.0037, 0.0955, 0.1505],
#         [0.0046, 0.0000, 0.0303,  ..., 0.0114, 0.0601, 0.1234]],
#        device='cuda:0')
# tensor([[0.0051, 0.0000, 0.0375,  ..., 0.0049, 0.0654, 0.1343],
#         [0.0325, 0.0000, 0.1852,  ..., 0.0139, 0.2713, 0.5563],
#         [0.0358, 0.0000, 0.2121,  ..., 0.0102, 0.3336, 0.6952],
#         ...,
#         [0.0250, 0.0000, 0.1319,  ..., 0.0100, 0.2235, 0.4404],
#         [0.0298, 0.0000, 0.1627,  ..., 0.0116, 0.2360, 0.4835],
#         [0.0093, 0.0000, 0.0689,  ..., 0.0091, 0.1021, 0.2088]],
#        device='cuda:0')
# tensor([[0.0085, 0.0000, 0.0620,  ..., 0.0014, 0.1463, 0.2037],
#         [0.0134, 0.0000, 0.0867,  ..., 0.0075, 0.1174, 0.2491],
#         [0.0105, 0.0000, 0.0668,  ..., 0.0053, 0.1114, 0.2271],
#         ...,
#         [0.0115, 0.0000, 0.0360,  ..., 0.0018, 0.0662, 0.1290],
#         [0.0244, 0.0008, 0.1307,  ..., 0.0065, 0.1842, 0.4396],
#         [0.0102, 0.0000, 0.0506,  ..., 0.0032, 0.0888, 0.1684]],
#        device='cuda:0')
# tensor([[0.0151, 0.0000, 0.0814,  ..., 0.0013, 0.1109, 0.2129],
#         [0.0136, 0.0000, 0.0612,  ..., 0.0002, 0.1132, 0.2383],
#         [0.0123, 0.0000, 0.0588,  ..., 0.0035, 0.1015, 0.2021],
#         ...,
#         [0.0132, 0.0000, 0.0578,  ..., 0.0021, 0.1074, 0.2377],
#         [0.0114, 0.0000, 0.0571,  ..., 0.0132, 0.0961, 0.1841],
#         [0.0103, 0.0000, 0.0562,  ..., 0.0129, 0.1025, 0.1929]],
#        device='cuda:0')
# tensor([[9.1428e-03, 0.0000e+00, 1.7302e-02,  ..., 1.0236e-02, 6.3217e-02,
#          1.1256e-01],
#         [1.1896e-02, 0.0000e+00, 6.3148e-02,  ..., 7.5039e-03, 1.1212e-01,
#          2.0989e-01],
#         [5.0774e-03, 0.0000e+00, 3.5232e-02,  ..., 5.7638e-05, 5.3462e-02,
#          1.2096e-01],
#         ...,
#         [3.6150e-05, 0.0000e+00, 1.2364e-02,  ..., 7.2931e-03, 2.6580e-02,
#          8.8785e-02],
#         [2.4998e-03, 0.0000e+00, 2.2058e-02,  ..., 2.3875e-03, 1.2056e-02,
#          5.7075e-02],
#         [3.1866e-02, 0.0000e+00, 1.8407e-01,  ..., 8.7109e-04, 2.4136e-01,
#          5.3048e-01]], device='cuda:0')
# tensor([[1.2231e-02, 0.0000e+00, 6.8259e-02,  ..., 2.2053e-04, 7.3793e-02,
#          1.6252e-01],
#         [1.3847e-02, 0.0000e+00, 6.8100e-02,  ..., 2.8341e-03, 6.5605e-02,
#          2.2035e-01],
#         [5.2632e-03, 0.0000e+00, 1.7175e-02,  ..., 5.2458e-03, 1.8317e-02,
#          6.0969e-02],
#         ...,
#         [3.6624e-03, 0.0000e+00, 4.1730e-03,  ..., 2.4568e-03, 1.1958e-02,
#          3.1493e-03],
#         [5.8462e-03, 0.0000e+00, 2.1989e-02,  ..., 4.5608e-03, 3.5908e-02,
#          9.7066e-02],
#         [1.1631e-02, 0.0000e+00, 4.9697e-02,  ..., 3.6813e-05, 7.6095e-02,
#          1.5361e-01]], device='cuda:0')
# tensor([[2.5784e-02, 0.0000e+00, 1.5079e-01,  ..., 1.7307e-03, 1.7932e-01,
#          5.0248e-01],
#         [3.0258e-02, 0.0000e+00, 1.4085e-01,  ..., 3.9489e-03, 2.1383e-01,
#          4.3487e-01],
#         [2.0643e-04, 0.0000e+00, 4.3620e-03,  ..., 6.1528e-03, 2.1656e-02,
#          1.3088e-03],
#         ...,
#         [4.9581e-03, 0.0000e+00, 1.7545e-03,  ..., 2.1174e-02, 2.9338e-02,
#          8.5731e-02],
#         [1.4085e-04, 0.0000e+00, 5.9369e-03,  ..., 4.7309e-03, 1.1720e-02,
#          3.3806e-02],
#         [2.2304e-02, 0.0000e+00, 1.4667e-01,  ..., 1.2833e-02, 2.2960e-01,
#          4.7491e-01]], device='cuda:0')
# tensor([[0.0165, 0.0000, 0.0863,  ..., 0.0096, 0.1738, 0.3019],
#         [0.0239, 0.0000, 0.1419,  ..., 0.0110, 0.2257, 0.4575],
#         [0.0353, 0.0000, 0.1832,  ..., 0.0060, 0.2706, 0.5940],
#         ...,
#         [0.0178, 0.0000, 0.0834,  ..., 0.0095, 0.1828, 0.3207],
#         [0.0352, 0.0000, 0.1621,  ..., 0.0038, 0.2765, 0.5673],
#         [0.0050, 0.0000, 0.0358,  ..., 0.0009, 0.0618, 0.1224]],
#        device='cuda:0')
# tensor([[9.6467e-03, 0.0000e+00, 6.0093e-02,  ..., 5.5656e-04, 1.3670e-01,
#          2.6235e-01],
#         [3.6553e-03, 0.0000e+00, 5.2488e-02,  ..., 1.4989e-04, 3.7789e-02,
#          1.2899e-01],
#         [1.1379e-02, 0.0000e+00, 6.7973e-02,  ..., 1.2677e-03, 9.7036e-02,
#          2.2776e-01],
#         ...,
#         [2.6414e-02, 0.0000e+00, 1.2947e-01,  ..., 1.4534e-02, 2.1620e-01,
#          4.2662e-01],
#         [7.9172e-03, 0.0000e+00, 3.2944e-02,  ..., 3.1438e-05, 2.6118e-02,
#          6.1294e-02],
#         [2.9349e-04, 0.0000e+00, 5.1832e-04,  ..., 8.4691e-04, 8.9040e-04,
#          1.6081e-04]], device='cuda:0')
# tensor([[0.0138, 0.0000, 0.1246,  ..., 0.0123, 0.1265, 0.2855],
#         [0.0226, 0.0000, 0.1186,  ..., 0.0079, 0.1873, 0.3817],
#         [0.0078, 0.0000, 0.0633,  ..., 0.0038, 0.0031, 0.0466],
#         ...,
#         [0.0169, 0.0000, 0.0928,  ..., 0.0016, 0.1698, 0.3221],
#         [0.0032, 0.0000, 0.0212,  ..., 0.0104, 0.0011, 0.0079],
#         [0.0086, 0.0000, 0.0429,  ..., 0.0025, 0.0785, 0.1738]],
#        device='cuda:0')
# tensor([[0.0070, 0.0000, 0.0211,  ..., 0.0018, 0.0103, 0.0791],
#         [0.0105, 0.0000, 0.0732,  ..., 0.0049, 0.0662, 0.1191],
#         [0.0014, 0.0000, 0.0157,  ..., 0.0094, 0.0194, 0.0155],
#         ...,
#         [0.0005, 0.0000, 0.0006,  ..., 0.0010, 0.0127, 0.0145],
#         [0.0071, 0.0000, 0.0359,  ..., 0.0062, 0.0584, 0.1180],
#         [0.0230, 0.0000, 0.1252,  ..., 0.0173, 0.2282, 0.4098]],
#        device='cuda:0')
# tensor([[0.0040, 0.0000, 0.0143,  ..., 0.0143, 0.0205, 0.0426],
#         [0.0008, 0.0000, 0.0048,  ..., 0.0007, 0.0417, 0.0443],
#         [0.0162, 0.0000, 0.0703,  ..., 0.0045, 0.1212, 0.2503],
#         ...,
#         [0.0068, 0.0000, 0.0321,  ..., 0.0149, 0.0339, 0.0010],
#         [0.0253, 0.0000, 0.1231,  ..., 0.0032, 0.2065, 0.4012],
#         [0.0320, 0.0000, 0.1929,  ..., 0.0060, 0.2702, 0.6311]],
#        device='cuda:0')
# tensor([[0.0168, 0.0000, 0.0582,  ..., 0.0099, 0.1751, 0.2762],
#         [0.0185, 0.0000, 0.1064,  ..., 0.0038, 0.1627, 0.3576],
#         [0.0148, 0.0000, 0.0719,  ..., 0.0029, 0.0943, 0.1959],
#         ...,
#         [0.0266, 0.0000, 0.1272,  ..., 0.0102, 0.2035, 0.3725],
#         [0.0021, 0.0090, 0.0356,  ..., 0.0005, 0.0569, 0.1324],
#         [0.0039, 0.0000, 0.0272,  ..., 0.0016, 0.0554, 0.0939]],
#        device='cuda:0', grad_fn=<AbsBackward>)
#   0%|          | 0/13 [00:00<?, ?it/s]
# tensor([[0.0235, 0.0000, 0.1010,  ..., 0.0141, 0.1760, 0.2838],
#         [0.0193, 0.0000, 0.0617,  ..., 0.0033, 0.1807, 0.2589],
#         [0.0070, 0.0000, 0.0500,  ..., 0.0075, 0.0936, 0.1720],
#         ...,
#         [0.0264, 0.0000, 0.0922,  ..., 0.0016, 0.2100, 0.3402],
#         [0.0072, 0.0000, 0.0352,  ..., 0.0088, 0.0705, 0.1086],
#         [0.0288, 0.0000, 0.0876,  ..., 0.0084, 0.2187, 0.3753]],
#        device='cuda:0')
# tensor([[2.6983e-02, 0.0000e+00, 1.1842e-01,  ..., 4.1082e-03, 2.0709e-01,
#          3.5772e-01],
#         [2.0405e-02, 0.0000e+00, 1.0601e-01,  ..., 8.8688e-03, 1.4917e-01,
#          2.7594e-01],
#         [2.7784e-02, 0.0000e+00, 1.3959e-01,  ..., 5.9420e-03, 2.8452e-01,
#          4.6734e-01],
#         ...,
#         [5.0644e-03, 0.0000e+00, 5.1389e-03,  ..., 1.2831e-03, 2.4042e-02,
#          8.4361e-03],
#         [5.7040e-03, 0.0000e+00, 2.6865e-02,  ..., 3.9283e-04, 8.3971e-02,
#          1.0941e-01],
#         [4.0773e-03, 0.0000e+00, 2.5211e-02,  ..., 1.0430e-02, 5.4465e-02,
#          1.0143e-01]], device='cuda:0')
# tensor([[0.0023, 0.0000, 0.0261,  ..., 0.0044, 0.0573, 0.1055],
#         [0.0268, 0.0000, 0.1488,  ..., 0.0114, 0.2497, 0.4473],
#         [0.0305, 0.0000, 0.1712,  ..., 0.0103, 0.3088, 0.5626],
#         ...,
#         [0.0201, 0.0000, 0.0973,  ..., 0.0072, 0.1947, 0.3342],
#         [0.0229, 0.0000, 0.1280,  ..., 0.0084, 0.2066, 0.3800],
#         [0.0082, 0.0000, 0.0614,  ..., 0.0065, 0.1035, 0.1854]],
#        device='cuda:0')
# tensor([[0.0023, 0.0000, 0.0410,  ..., 0.0022, 0.1241, 0.1385],
#         [0.0112, 0.0000, 0.0748,  ..., 0.0046, 0.1178, 0.2211],
#         [0.0079, 0.0000, 0.0532,  ..., 0.0004, 0.0962, 0.1751],
#         ...,
#         [0.0094, 0.0000, 0.0273,  ..., 0.0014, 0.0560, 0.1025],
#         [0.0191, 0.0008, 0.0999,  ..., 0.0052, 0.1543, 0.3402],
#         [0.0111, 0.0000, 0.0448,  ..., 0.0022, 0.0845, 0.1345]],
#        device='cuda:0')
# tensor([[1.1884e-02, 0.0000e+00, 6.4929e-02,  ..., 2.5163e-03, 1.0129e-01,
#          1.6941e-01],
#         [1.0669e-02, 0.0000e+00, 4.5560e-02,  ..., 6.2171e-04, 9.7887e-02,
#          1.7991e-01],
#         [9.8083e-03, 0.0000e+00, 4.5094e-02,  ..., 1.2441e-04, 8.9192e-02,
#          1.5447e-01],
#         ...,
#         [1.0024e-02, 0.0000e+00, 4.4287e-02,  ..., 7.3683e-03, 9.7887e-02,
#          1.8586e-01],
#         [9.6336e-03, 0.0000e+00, 4.1415e-02,  ..., 1.0858e-02, 8.8005e-02,
#          1.4359e-01],
#         [7.2104e-03, 0.0000e+00, 4.0938e-02,  ..., 1.0560e-02, 9.3773e-02,
#          1.5004e-01]], device='cuda:0')
# tensor([[1.1197e-02, 0.0000e+00, 1.1967e-02,  ..., 1.1089e-02, 5.7507e-02,
#          8.3564e-02],
#         [1.1431e-02, 0.0000e+00, 5.4161e-02,  ..., 2.3015e-03, 1.0520e-01,
#          1.7147e-01],
#         [4.5973e-03, 0.0000e+00, 2.9058e-02,  ..., 6.5530e-04, 5.2694e-02,
#          1.0727e-01],
#         ...,
#         [1.9880e-03, 0.0000e+00, 1.7425e-02,  ..., 3.4952e-03, 3.5331e-02,
#          9.1087e-02],
#         [2.9365e-04, 0.0000e+00, 1.7322e-02,  ..., 6.7840e-04, 1.0803e-02,
#          5.1264e-02],
#         [2.9740e-02, 0.0000e+00, 1.4808e-01,  ..., 5.0109e-03, 2.1719e-01,
#          4.2156e-01]], device='cuda:0')
# tensor([[0.0119, 0.0000, 0.0671,  ..., 0.0023, 0.0768, 0.1677],
#         [0.0112, 0.0000, 0.0628,  ..., 0.0008, 0.0600, 0.2041],
#         [0.0038, 0.0000, 0.0145,  ..., 0.0010, 0.0186, 0.0539],
#         ...,
#         [0.0042, 0.0000, 0.0028,  ..., 0.0006, 0.0106, 0.0039],
#         [0.0042, 0.0000, 0.0220,  ..., 0.0013, 0.0372, 0.0887],
#         [0.0102, 0.0000, 0.0373,  ..., 0.0016, 0.0661, 0.1198]],
#        device='cuda:0')
# tensor([[0.0205, 0.0000, 0.1273,  ..., 0.0032, 0.1779, 0.4207],
#         [0.0275, 0.0000, 0.1155,  ..., 0.0029, 0.1981, 0.3554],
#         [0.0005, 0.0000, 0.0012,  ..., 0.0086, 0.0251, 0.0062],
#         ...,
#         [0.0076, 0.0000, 0.0080,  ..., 0.0158, 0.0325, 0.0753],
#         [0.0010, 0.0000, 0.0032,  ..., 0.0036, 0.0079, 0.0235],
#         [0.0186, 0.0000, 0.1192,  ..., 0.0132, 0.2149, 0.3867]],
#        device='cuda:0')
# tensor([[1.3197e-02, 0.0000e+00, 6.1932e-02,  ..., 5.3551e-03, 1.5424e-01,
#          2.2371e-01],
#         [1.8727e-02, 0.0000e+00, 1.0760e-01,  ..., 9.3261e-03, 1.9597e-01,
#          3.4986e-01],
#         [2.9416e-02, 0.0000e+00, 1.4256e-01,  ..., 3.3057e-03, 2.4252e-01,
#          4.6453e-01],
#         ...,
#         [1.2878e-02, 0.0000e+00, 6.1472e-02,  ..., 9.6685e-03, 1.6365e-01,
#          2.4026e-01],
#         [3.1418e-02, 0.0000e+00, 1.2749e-01,  ..., 3.0804e-04, 2.4506e-01,
#          4.4241e-01],
#         [4.4242e-03, 0.0000e+00, 2.7111e-02,  ..., 2.4934e-04, 5.1763e-02,
#          8.6470e-02]], device='cuda:0')
# tensor([[0.0088, 0.0000, 0.0474,  ..., 0.0012, 0.1268, 0.2026],
#         [0.0012, 0.0000, 0.0451,  ..., 0.0013, 0.0353, 0.1133],
#         [0.0097, 0.0000, 0.0630,  ..., 0.0050, 0.1052, 0.2114],
#         ...,
#         [0.0218, 0.0000, 0.0949,  ..., 0.0114, 0.1853, 0.3177],
#         [0.0045, 0.0000, 0.0261,  ..., 0.0012, 0.0278, 0.0563],
#         [0.0006, 0.0000, 0.0011,  ..., 0.0011, 0.0008, 0.0027]],
#        device='cuda:0')
# tensor([[0.0071, 0.0000, 0.0899,  ..., 0.0100, 0.1125, 0.2287],
#         [0.0169, 0.0000, 0.0913,  ..., 0.0042, 0.1638, 0.2986],
#         [0.0056, 0.0000, 0.0539,  ..., 0.0038, 0.0064, 0.0576],
#         ...,
#         [0.0161, 0.0000, 0.0751,  ..., 0.0034, 0.1520, 0.2498],
#         [0.0049, 0.0000, 0.0160,  ..., 0.0118, 0.0083, 0.0123],
#         [0.0052, 0.0000, 0.0297,  ..., 0.0039, 0.0639, 0.1277]],
#        device='cuda:0')
# tensor([[6.9201e-03, 0.0000e+00, 2.0377e-02,  ..., 8.9114e-04, 1.6805e-02,
#          7.7597e-02],
#         [9.3854e-03, 0.0000e+00, 6.7337e-02,  ..., 6.3145e-03, 7.5757e-02,
#          1.2659e-01],
#         [2.4634e-03, 0.0000e+00, 1.2964e-02,  ..., 3.2203e-03, 1.6330e-02,
#          1.0463e-02],
#         ...,
#         [4.3660e-06, 0.0000e+00, 7.5169e-04,  ..., 1.1209e-03, 1.0416e-02,
#          1.0270e-02],
#         [6.4620e-03, 0.0000e+00, 2.4972e-02,  ..., 2.2129e-03, 4.7778e-02,
#          8.4755e-02],
#         [1.9444e-02, 0.0000e+00, 9.6369e-02,  ..., 1.4278e-02, 1.9994e-01,
#          3.1760e-01]], device='cuda:0')
# tensor([[7.1609e-03, 0.0000e+00, 7.2443e-03,  ..., 1.2287e-02, 2.2855e-02,
#          3.9604e-02],
#         [8.5731e-04, 0.0000e+00, 1.9344e-03,  ..., 2.1973e-03, 3.5014e-02,
#          3.0971e-02],
#         [1.4430e-02, 0.0000e+00, 5.4878e-02,  ..., 1.0587e-03, 1.0245e-01,
#          1.9554e-01],
#         ...,
#         [4.8445e-03, 0.0000e+00, 2.5337e-02,  ..., 9.5234e-03, 3.2537e-02,
#          4.2635e-04],
#         [2.1238e-02, 0.0000e+00, 9.1556e-02,  ..., 3.2190e-03, 1.8024e-01,
#          3.0332e-01],
#         [2.3999e-02, 0.0000e+00, 1.5106e-01,  ..., 1.8121e-03, 2.4007e-01,
#          4.9796e-01]], device='cuda:0')
# tensor([[1.9622e-02, 0.0000e+00, 1.2885e-01,  ..., 1.8193e-02, 2.1205e-01,
#          3.6336e-01],
#         [9.4627e-03, 0.0000e+00, 3.1559e-02,  ..., 2.2167e-04, 6.1824e-02,
#          1.0314e-01],
#         [1.8496e-02, 0.0000e+00, 9.5055e-02,  ..., 1.5630e-02, 1.7925e-01,
#          2.9240e-01],
#         ...,
#         [3.9441e-03, 0.0000e+00, 3.5908e-02,  ..., 5.2697e-03, 7.9258e-02,
#          6.4019e-02],
#         [1.0621e-02, 0.0000e+00, 7.7523e-02,  ..., 1.3792e-02, 9.4749e-02,
#          1.7681e-01],
#         [5.8387e-03, 0.0000e+00, 1.3617e-02,  ..., 2.2143e-03, 4.8130e-02,
#          1.8868e-02]], device='cuda:0', grad_fn=<AbsBackward>)
#   0%|          | 0/13 [00:00<?, ?it/s]
# tensor([[0.0055, 0.0095, 0.0465,  ..., 0.0116, 0.1002, 0.1133],
#         [0.0081, 0.0095, 0.0236,  ..., 0.0033, 0.0708, 0.0786],
#         [0.0027, 0.0096, 0.0186,  ..., 0.0029, 0.0467, 0.0570],
#         ...,
#         [0.0116, 0.0000, 0.0190,  ..., 0.0049, 0.0543, 0.0612],
#         [0.0027, 0.0000, 0.0035,  ..., 0.0085, 0.0188, 0.0130],
#         [0.0113, 0.0012, 0.0212,  ..., 0.0017, 0.0606, 0.0788]],
#        device='cuda:0')
# tensor([[0.0030, 0.0012, 0.0274,  ..., 0.0057, 0.0679, 0.0783],
#         [0.0015, 0.0011, 0.0252,  ..., 0.0084, 0.0518, 0.0611],
#         [0.0005, 0.0134, 0.0374,  ..., 0.0044, 0.0927, 0.1131],
#         ...,
#         [0.0044, 0.0000, 0.0020,  ..., 0.0047, 0.0024, 0.0051],
#         [0.0013, 0.0000, 0.0097,  ..., 0.0027, 0.0276, 0.0279],
#         [0.0012, 0.0066, 0.0032,  ..., 0.0042, 0.0163, 0.0258]],
#        device='cuda:0')
# tensor([[0.0007, 0.0026, 0.0035,  ..., 0.0008, 0.0151, 0.0161],
#         [0.0085, 0.0027, 0.0513,  ..., 0.0050, 0.1092, 0.1287],
#         [0.0055, 0.0164, 0.0558,  ..., 0.0046, 0.1326, 0.1655],
#         ...,
#         [0.0030, 0.0071, 0.0203,  ..., 0.0061, 0.0624, 0.0744],
#         [0.0026, 0.0050, 0.0301,  ..., 0.0086, 0.0633, 0.0871],
#         [0.0018, 0.0050, 0.0261,  ..., 0.0075, 0.0583, 0.0686]],
#        device='cuda:0')
# tensor([[0.0003, 0.0045, 0.0058,  ..., 0.0011, 0.0287, 0.0147],
#         [0.0006, 0.0010, 0.0219,  ..., 0.0071, 0.0498, 0.0621],
#         [0.0002, 0.0000, 0.0109,  ..., 0.0044, 0.0294, 0.0412],
#         ...,
#         [0.0016, 0.0000, 0.0055,  ..., 0.0006, 0.0188, 0.0273],
#         [0.0014, 0.0049, 0.0265,  ..., 0.0068, 0.0589, 0.0852],
#         [0.0030, 0.0000, 0.0133,  ..., 0.0006, 0.0240, 0.0289]],
#        device='cuda:0')
# tensor([[0.0018, 0.0000, 0.0161,  ..., 0.0053, 0.0333, 0.0359],
#         [0.0013, 0.0005, 0.0128,  ..., 0.0002, 0.0347, 0.0432],
#         [0.0008, 0.0000, 0.0115,  ..., 0.0019, 0.0293, 0.0337],
#         ...,
#         [0.0022, 0.0075, 0.0144,  ..., 0.0018, 0.0443, 0.0510],
#         [0.0023, 0.0075, 0.0125,  ..., 0.0035, 0.0364, 0.0399],
#         [0.0012, 0.0055, 0.0108,  ..., 0.0043, 0.0388, 0.0426]],
#        device='cuda:0')
# tensor([[6.6686e-03, 0.0000e+00, 7.4742e-03,  ..., 6.8045e-03, 1.2921e-02,
#          2.1954e-02],
#         [1.2163e-03, 7.1561e-03, 1.5693e-02,  ..., 2.2274e-03, 4.2570e-02,
#          4.7300e-02],
#         [6.3032e-05, 3.9416e-03, 1.1182e-02,  ..., 1.1310e-03, 2.7459e-02,
#          4.0714e-02],
#         ...,
#         [1.6740e-03, 0.0000e+00, 1.5153e-02,  ..., 4.2474e-03, 2.9113e-02,
#          4.3836e-02],
#         [3.1338e-04, 5.0040e-04, 8.4571e-03,  ..., 8.4910e-04, 1.1236e-02,
#          1.8912e-02],
#         [7.0338e-03, 0.0000e+00, 3.9307e-02,  ..., 8.2724e-03, 7.5456e-02,
#          9.4352e-02]], device='cuda:0')
# tensor([[0.0007, 0.0000, 0.0268,  ..., 0.0069, 0.0469, 0.0682],
#         [0.0025, 0.0026, 0.0272,  ..., 0.0008, 0.0443, 0.0818],
#         [0.0007, 0.0000, 0.0054,  ..., 0.0033, 0.0111, 0.0225],
#         ...,
#         [0.0031, 0.0000, 0.0050,  ..., 0.0041, 0.0055, 0.0144],
#         [0.0005, 0.0012, 0.0097,  ..., 0.0005, 0.0188, 0.0294],
# ...
#          0.0000e+00],
#         ...,
#         [1.8164e-03, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00, 0.0000e+00,
#          0.0000e+00],
#         [9.5907e-04, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00, 0.0000e+00,
#          0.0000e+00],
#         [2.2916e-03, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00, 0.0000e+00,
#          0.0000e+00]], device='cuda:0')
# tensor([[0.0010, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0053, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0042, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         ...,
#         [0.0025, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0019, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0023, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        device='cuda:0')
# tensor([[0.0003, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0003, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0009, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         ...,
#         [0.0087, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0024, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0016, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        device='cuda:0')
# tensor([[0.0031, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0019, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0039, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         ...,
#         [0.0011, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0022, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0026, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        device='cuda:0')
# tensor([[0.0009, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0005, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0002, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         ...,
#         [0.0005, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0024, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0019, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        device='cuda:0')
# tensor([[6.8113e-05, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00, 0.0000e+00,
#          0.0000e+00],
#         [2.7235e-03, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00, 0.0000e+00,
#          0.0000e+00],
#         [5.0724e-03, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00, 0.0000e+00,
#          0.0000e+00],
#         ...,
#         [1.0878e-03, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00, 0.0000e+00,
#          0.0000e+00],
#         [5.2039e-03, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00, 0.0000e+00,
#          0.0000e+00],
#         [3.1840e-03, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00, 0.0000e+00,
#          0.0000e+00]], device='cuda:0')
# tensor([[9.8705e-05, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00, 0.0000e+00,
#          0.0000e+00],
#         [5.1421e-03, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00, 0.0000e+00,
#          0.0000e+00],
#         [9.3082e-04, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00, 0.0000e+00,
#          0.0000e+00],
#         ...,
#         [1.3920e-03, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00, 0.0000e+00,
#          0.0000e+00],
#         [5.4861e-03, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00, 0.0000e+00,
#          0.0000e+00],
#         [3.1570e-04, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00, 0.0000e+00,
#          0.0000e+00]], device='cuda:0', grad_fn=<AbsBackward>)
#   0%|          | 0/13 [00:00<?, ?it/s]
# tensor([[0.0052, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0025, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0023, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         ...,
#         [0.0011, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0004, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0039, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        device='cuda:0')
# tensor([[0.0016, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0008, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0012, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         ...,
#         [0.0004, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0015, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0019, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        device='cuda:0')
# tensor([[1.5844e-03, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00, 0.0000e+00,
#          0.0000e+00],
#         [9.6271e-03, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00, 0.0000e+00,
#          0.0000e+00],
#         [1.0037e-02, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00, 0.0000e+00,
#          0.0000e+00],
#         ...,
#         [2.7848e-03, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00, 0.0000e+00,
#          0.0000e+00],
#         [1.7226e-05, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00, 0.0000e+00,
#          0.0000e+00],
#         [1.4061e-03, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00, 0.0000e+00,
#          0.0000e+00]], device='cuda:0')
# tensor([[0.0052, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0004, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0026, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         ...,
#         [0.0082, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0114, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0049, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        device='cuda:0')
# tensor([[0.0019, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0059, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0007, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         ...,
#         [0.0052, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0044, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0037, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        device='cuda:0')
# tensor([[0.0020, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0008, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0040, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         ...,
#         [0.0027, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0032, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0007, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        device='cuda:0')
# tensor([[0.0017, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0042, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0031, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         ...,
#         [0.0011, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0005, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0002, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        device='cuda:0')
# tensor([[0.0054, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0028, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0005, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         ...,
#         [0.0025, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0013, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0030, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        device='cuda:0')
# tensor([[0.0010, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0067, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0050, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         ...,
#         [0.0033, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0033, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0030, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        device='cuda:0')
# tensor([[0.0007, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0005, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0012, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         ...,
#         [0.0109, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0031, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0022, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        device='cuda:0')
# tensor([[0.0038, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0022, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0052, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         ...,
#         [0.0019, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0031, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0031, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        device='cuda:0')
# tensor([[1.7536e-03, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00, 0.0000e+00,
#          0.0000e+00],
#         [5.5806e-04, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00, 0.0000e+00,
#          0.0000e+00],
#         [8.6300e-05, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00, 0.0000e+00,
#          0.0000e+00],
#         ...,
#         [3.3216e-04, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00, 0.0000e+00,
#          0.0000e+00],
#         [3.4229e-03, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00, 0.0000e+00,
#          0.0000e+00],
#         [2.6669e-03, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00, 0.0000e+00,
#          0.0000e+00]], device='cuda:0')
# tensor([[0.0003, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0036, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0062, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         ...,
#         [0.0017, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0066, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0037, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        device='cuda:0')
#   0%|          | 0/13 [00:00<?, ?it/s]
# tensor([[0.0052, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0025, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0023, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         ...,
#         [0.0011, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0004, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0039, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        device='cuda:0')
# tensor([[0.0016, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0008, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0012, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         ...,
#         [0.0004, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0015, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0019, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        device='cuda:0')
# tensor([[1.5844e-03, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00, 0.0000e+00,
#          0.0000e+00],
#         [9.6271e-03, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00, 0.0000e+00,
#          0.0000e+00],
#         [1.0037e-02, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00, 0.0000e+00,
#          0.0000e+00],
#         ...,
#         [2.7848e-03, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00, 0.0000e+00,
#          0.0000e+00],
#         [1.7226e-05, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00, 0.0000e+00,
#          0.0000e+00],
#         [1.4061e-03, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00, 0.0000e+00,
#          0.0000e+00]], device='cuda:0')
# tensor([[0.0052, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0004, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0026, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         ...,
#         [0.0082, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0114, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0049, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        device='cuda:0')
# tensor([[0.0019, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0059, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0007, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         ...,
#         [0.0052, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0044, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0037, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        device='cuda:0')
# tensor([[0.0020, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0008, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0040, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         ...,
#         [0.0027, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0032, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0007, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        device='cuda:0')
# tensor([[0.0017, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0042, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0031, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         ...,
#         [0.0011, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0005, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0002, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        device='cuda:0')
# tensor([[0.0054, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0028, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0005, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         ...,
#         [0.0025, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0013, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0030, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        device='cuda:0')
# tensor([[0.0010, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0067, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0050, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         ...,
#         [0.0033, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0033, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0030, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        device='cuda:0')
# tensor([[0.0007, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0005, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0012, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         ...,
#         [0.0109, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0031, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0022, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        device='cuda:0')
# tensor([[0.0038, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0022, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0052, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         ...,
#         [0.0019, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0031, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0031, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        device='cuda:0')
# tensor([[1.7536e-03, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00, 0.0000e+00,
#          0.0000e+00],
#         [5.5806e-04, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00, 0.0000e+00,
#          0.0000e+00],
#         [8.6300e-05, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00, 0.0000e+00,
#          0.0000e+00],
#         ...,
#         [3.3216e-04, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00, 0.0000e+00,
#          0.0000e+00],
#         [3.4229e-03, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00, 0.0000e+00,
#          0.0000e+00],
#         [2.6669e-03, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00, 0.0000e+00,
#          0.0000e+00]], device='cuda:0')
# tensor([[0.0003, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0036, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0062, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         ...,
#         [0.0017, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0066, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0037, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000]],
#        device='cuda:0')
# Epoch [1/20], Train Loss: 0.6948, Train Acc: 0.4902, Valid Loss: 0.6937,  Valid Acc: 0.5000
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-78b672a452fe> in <module>
#       9
#      10
# ---> 11 TRAIN_VGG(model, train_loaderRGB, valid_loaderRGB, num_epochs, criterion, optimizer, best_val_loss,threshold, device, save_path)
#
# <ipython-input-12-bf98dfd35784> in TRAIN_VGG(net, train_loader, valid_loader, num_epochs, criterion, optimizer, val_loss, threshold, device, save_name)
#     105         if valid_loss < best_val_loss:
#     106             best_val_loss = valid_loss
# --> 107             save_checkpoint(save_name, net, optimizer, best_val_loss)
#     108
#     109     plt.plot(step_list,training_loss_list,label="Training Loss")
#
# NameError: name 'save_checkpoint' is not defined
